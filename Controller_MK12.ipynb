# %%
import os
import datetime
import pygame
import random
import math
import time
import numpy as np
import json  # for saving log data
from stable_baselines3 import PPO
from pygame._sdl2.video import Window, Renderer, Texture

# -----------------------------------------------------------
# Force Sensor Integration (extracted from your force sensor code)
# -----------------------------------------------------------

import tkinter as tk
from tkinter import ttk
import serial as pyserial
import threading
from collections import deque

###############################################################################
# Multi-Seed Setup
###############################################################################
SCENARIO_SEEDS = [0, 2, 58]  # We will run the experiment for each of these seeds in turn.

###############################################################################
# Global flags & constants
###############################################################################
USE_FORCE_SENSOR = False  # toggle with F key
force_sensor_input = [0.0, 0.0]
FORCE_SENSOR_AVAILABLE = False

gamma1_listening = None
FORCE_SENSOR_SCALE_X = 5.0
FORCE_SENSOR_SCALE_Y = 5.0

XY_FORCE_CAL = 1.33
Z_SMOOTH_ALPHA = 0.2

skip_remaining_seeds = False
current_gamma_mode = None
gamma_mode_index = 0

sample_prev_fs = None
sample_curr_fs = None
sample_lock_fs = threading.Lock()
last_fx_smooth = None
last_fy_smooth = None

try:
    ser = pyserial.Serial('COM5', 115200, timeout=0.01)
    FORCE_SENSOR_AVAILABLE = True
    print("Force sensor connected successfully.")
except Exception as e:
    print("Error: Could not open serial port:", e)
    ser = None
    FORCE_SENSOR_AVAILABLE = False
    print("Force sensor not available. Using keyboard/joystick controls only.")

def serial_reader_fs():
    global sample_prev_fs, sample_curr_fs, last_fx_smooth, last_fy_smooth, force_sensor_input
    while True:
        if ser is None:
            time.sleep(0.1)
            continue
        try:
            line = ser.readline().decode('utf-8').strip()
            if not line:
                continue
            tokens = line.split(',')
            if len(tokens) != 2:
                continue
            try:
                values = list(map(float, tokens))
            except Exception:
                continue
            sample = {
                'fx': -values[0],
                'fy': values[1],
                'timestamp': time.time()
            }
            with sample_lock_fs:
                if sample_curr_fs is None:
                    sample_curr_fs = sample
                    sample_prev_fs = sample
                else:
                    sample_prev_fs = sample_curr_fs
                    sample_curr_fs = sample

            # Interpolate horizontal forces
            with sample_lock_fs:
                sp = sample_prev_fs
                sc = sample_curr_fs
            now = time.time()
            if sp is None or sc is None:
                continue
            t0 = sp['timestamp']
            t1 = sc['timestamp']
            fraction = 1.0 if t1 == t0 else (now - t0) / (t1 - t0)
            fraction = max(0.0, min(1.0, fraction))
            fx_interp = sp['fx'] * (1 - fraction) + sc['fx'] * fraction
            fy_interp = sp['fy'] * (1 - fraction) + sc['fy'] * fraction

            # Exponential smoothing
            if last_fx_smooth is None:
                smoothed_fx = fx_interp
            else:
                smoothed_fx = last_fx_smooth + Z_SMOOTH_ALPHA * (fx_interp - last_fx_smooth)
            if last_fy_smooth is None:
                smoothed_fy = fy_interp
            else:
                smoothed_fy = last_fy_smooth + Z_SMOOTH_ALPHA * (fy_interp - last_fy_smooth)
            last_fx_smooth = smoothed_fx
            last_fy_smooth = smoothed_fy

            # Scale with calibration
            final_fx = smoothed_fx * XY_FORCE_CAL
            final_fy = smoothed_fy * XY_FORCE_CAL
            final_fx *= FORCE_SENSOR_SCALE_X
            final_fy *= FORCE_SENSOR_SCALE_Y

            force_sensor_input = [final_fx, final_fy]
        except Exception as e:
            print("Serial reader error:", e)
            time.sleep(0.01)

if FORCE_SENSOR_AVAILABLE:
    threading.Thread(target=serial_reader_fs, daemon=True).start()

pygame.init()
pygame.joystick.init()

USE_AI_CONTROL = False

# Noise Models
def eeg_noise():
    """ Default: Gaussian EEG noise with σ=190. """
    return np.random.normal(0, 190)

def burst_noise():
    """ Rare large deviations (~20% prob). """
    return np.random.choice([-1,1]) * np.random.normal(0, 190) * (np.random.rand() < 0.2)

from scipy.signal import lfilter
def pink_noise():
    """ Pink noise (1/f). """
    a = [1, -0.95]
    return lfilter([1], a, np.random.normal(0, 290, size=1))[0]

NOISE_FUNCTION = pink_noise  # or burst_noise, etc.

###############################################################################
# Config / Constants
###############################################################################
FULL_VIEW_SIZE = (1200, 800)
RED_ONLY_SIZE  = (1200, 800)

NOISE_MAGNITUDE = 2.5
MIN_NOISE = 0.0
MAX_NOISE = 2.0
NOISE_STEP = 0.1

OLD_WINDOW_SIZE   = (600, 600)
SCALING_FACTOR_X  = FULL_VIEW_SIZE[0] / OLD_WINDOW_SIZE[0]
SCALING_FACTOR_Y  = FULL_VIEW_SIZE[1] / OLD_WINDOW_SIZE[1]
SCALING_FACTOR    = (SCALING_FACTOR_X + SCALING_FACTOR_Y) / 2

WHITE  = (255, 255, 255)
BLACK  = (0, 0, 0)
RED    = (255, 0, 0)
GREEN  = (0, 200, 0)
BLUE   = (0, 0, 255)
YELLOW = (255, 255, 0)
GRAY   = (128, 128, 128)

FONT_COLOR = (0, 0, 0)
FONT_SIZE = int(16 * SCALING_FACTOR)
ARROW_LENGTH = int(60 * SCALING_FACTOR)

OBSTACLE_RADIUS  = int(10 * SCALING_FACTOR)
COLLISION_BUFFER = int(5 * SCALING_FACTOR)
ENABLE_OBSTACLES = True
MAX_SPEED        = 3 * SCALING_FACTOR

DOT_RADIUS            = int(15 * SCALING_FACTOR)
TARGET_RADIUS         = int(10 * SCALING_FACTOR)
GOAL_DETECTION_RADIUS = DOT_RADIUS + TARGET_RADIUS

GHOST_TRAIL_DURATION  = 3.0
recent_positions      = []
last_reset_time       = time.time()

RECENT_DIR_LOOKBACK   = 1.0
GOAL_SWITCH_THRESHOLD = 0.05

WINDOW_CENTER = (FULL_VIEW_SIZE[0] // 2, FULL_VIEW_SIZE[1] // 2)
START_POS = [WINDOW_CENTER[0], WINDOW_CENTER[1]]
dot_pos   = START_POS.copy()

gamma         = 0.2
reached_goal  = False
targets       = []
current_target_idx = 0
obstacles     = []

goal_counters = {}
failure_counter = 0

USE_RAW_ONLY_FOR_GOAL_DETECTION = True

joystick = None
if pygame.joystick.get_count() > 0:
    joystick = pygame.joystick.Joystick(0)
    joystick.init()
    print("Joystick initialized:", joystick.get_name())
else:
    print("No joystick detected.")

AXIS_L2 = 4
AXIS_R2 = 5

window1 = Window("2D Environment: Full View", size=FULL_VIEW_SIZE)
renderer1 = Renderer(window1, vsync=True)
window2 = Window("2D Environment: Red Arrow Only", size=RED_ONLY_SIZE)
renderer2 = Renderer(window2, vsync=True)

def create_compatible_surface(size):
    return pygame.Surface(size, flags=pygame.SRCALPHA)

surface_full = create_compatible_surface(FULL_VIEW_SIZE)
surface_red_only = create_compatible_surface(RED_ONLY_SIZE)

font = pygame.font.Font(None, FONT_SIZE)

def surface_to_texture(renderer, surf):
    if surf.get_bitsize() != 32:
        surf = surf.convert_alpha()
    return Texture.from_surface(renderer, surf)

def distance(pos1, pos2):
    return math.hypot(pos1[0] - pos2[0], pos1[1] - pos2[1])

# Correct line_circle_intersection
def line_circle_intersection(start, end, circle_center, radius):
    dx = end[0] - start[0]
    dy = end[1] - start[1]
    cx = circle_center[0] - start[0]
    cy = circle_center[1] - start[1]
    l2 = dx*dx + dy*dy
    if l2 == 0:
        return distance(start, circle_center) <= radius
    t = max(0, min(1, (cx*dx + cy*dy) / l2))
    proj_x = start[0] + t * dx
    proj_y = start[1] + t * dy
    return distance((proj_x, proj_y), circle_center) <= radius

def check_collision(pos, new_pos):
    if not ENABLE_OBSTACLES:
        return False
    for obstacle_pos in obstacles:
        if line_circle_intersection(pos, new_pos, obstacle_pos, OBSTACLE_RADIUS + COLLISION_BUFFER):
            return True
    return False

def inside_obstacle(pos):
    if not ENABLE_OBSTACLES:
        return False
    for obstacle_pos in obstacles:
        if distance(pos, obstacle_pos) <= (OBSTACLE_RADIUS + DOT_RADIUS):
            return True
    return False

def get_recent_direction():
    if len(recent_positions) < 2:
        return [0, 0]
    current_time = time.time()
    valid_points = []
    for (x, y, t) in reversed(recent_positions):
        if (current_time - t) <= RECENT_DIR_LOOKBACK:
            valid_points.append((x, y, t))
        else:
            break
    if len(valid_points) < 2:
        return [0, 0]
    valid_points.sort(key=lambda p: p[2])
    x1, y1, t1 = valid_points[0]
    x2, y2, t2 = valid_points[-1]
    dt = t2 - t1
    if dt < 0.001:
        return [0, 0]
    vx = (x2 - x1) / dt
    vy = (y2 - y1) / dt
    mag = math.hypot(vx, vy)
    return [vx/mag, vy/mag] if mag > 0 else [0, 0]

def compute_perfect_direction(dot_pos, goal_pos, obstacles):
    gx = goal_pos[0] - dot_pos[0]
    gy = goal_pos[1] - dot_pos[1]
    goal_dist = math.hypot(gx, gy)
    if goal_dist < 1e-6:
        return [0, 0]
    goal_dir = [gx / goal_dist, gy / goal_dist]

    repulse_x = 0.0
    repulse_y = 0.0
    repulsion_radius = 27 * SCALING_FACTOR
    repulsion_gain   = 30000.0

    for obs in obstacles:
        dx = dot_pos[0] - obs[0]
        dy = dot_pos[1] - obs[1]
        dist_o = math.hypot(dx, dy)
        if dist_o < 1e-6:
            continue
        if dist_o < repulsion_radius:
            push_dir_x = dx / dist_o
            push_dir_y = dy / dist_o
            strength = repulsion_gain / (dist_o**2)
            repulse_x += push_dir_x * strength
            repulse_y += push_dir_y * strength

    w_px = goal_dir[0] + repulse_x
    w_py = goal_dir[1] + repulse_y
    norm = math.hypot(w_px, w_py)
    if norm < 1e-6:
        return [0, 0]
    return [w_px / norm, w_py / norm]

class GammaPredictor:
    def __init__(self, model_path="gamma_ppo_model.zip"):
        try:
            self.model = PPO.load(model_path)
        except:
            self.model = None
        self.max_dist = np.sqrt(FULL_VIEW_SIZE[0]**2 + FULL_VIEW_SIZE[1]**2)

    def prepare_observation(self, dot_pos, target_pos, human_input):
        dot_pos = np.array(dot_pos, dtype=np.float32)
        target_pos = np.array(target_pos, dtype=np.float32)
        to_target = target_pos - dot_pos
        dist = np.linalg.norm(to_target)
        perfect_dir = to_target / dist if dist > 0 else np.array([0, 0], dtype=np.float32)
        h_mag = np.linalg.norm(human_input)
        human_dir = human_input / h_mag if h_mag > 0 else np.array([0, 0], dtype=np.float32)
        normalized_dist = dist / self.max_dist
        obs_dist_ratio = 1.0
        obs = np.concatenate([
            dot_pos,
            human_dir,
            target_pos,
            perfect_dir,
            [normalized_dist],
            [obs_dist_ratio]
        ]).astype(np.float32)
        return obs

    def predict_gamma(self, dot_pos, target_pos, human_input):
        if self.model is None:
            return 0.2
        obs = self.prepare_observation(dot_pos, target_pos, human_input)
        obs_batched = obs[np.newaxis, :]
        action, _ = self.model.predict(obs_batched, deterministic=True)
        return float(action[0])

gamma_predictor = GammaPredictor()

def predict_human_target(human_input):
    global current_target_idx
    
    # If no targets, just return current index
    if len(targets) == 0:
        return current_target_idx
        
    # Calculate distance to current target
    dist_to_current = distance(dot_pos, targets[current_target_idx])
    
    # If human input is negligible, maintain current target
    if human_input[0] == 0 and human_input[1] == 0:
        return current_target_idx
        
    # Calculate human input direction
    h_mag = math.hypot(human_input[0], human_input[1])
    if h_mag <= 1e-6:
        return current_target_idx
    h_dir = [h_input/h_mag for h_input in human_input]
    
    # Get recent movement direction if needed
    recent_dir = [0, 0]
    if not USE_RAW_ONLY_FOR_GOAL_DETECTION:
        recent_dir = get_recent_direction()
    
    # Calculate scores for each target
    best_score = float('-inf')
    best_idx = current_target_idx
    
    # Goal-change resistance factors
    # Make it harder to change when already near a goal
    close_threshold = GOAL_DETECTION_RADIUS * 5  # Expanded zone where changing is difficult
    very_close_threshold = GOAL_DETECTION_RADIUS * 2  # Zone where changing is extremely difficult
    
    # Calculate resistance factor based on distance to current goal
    resistance_factor = 0.0
    if dist_to_current < very_close_threshold:
        # Extremely difficult to change when very close
        resistance_factor = 0.8
    elif dist_to_current < close_threshold:
        # Linear increase in difficulty as you get closer
        resistance_factor = 0.4 * (1.0 - (dist_to_current - very_close_threshold) / 
                                   (close_threshold - very_close_threshold))
    
    # If we're in AI control mode, make goal switching even harder
    if USE_AI_CONTROL:
        resistance_factor += 0.2
    resistance_factor = min(resistance_factor, 0.95)  # Cap at 0.95
    
    for i, targ in enumerate(targets):
        # Skip calculation for current target
        if i == current_target_idx:
            continue
            
        # Calculate direction to this target
        to_tx = targ[0] - dot_pos[0]
        to_ty = targ[1] - dot_pos[1]
        to_mag = math.hypot(to_tx, to_ty)
        if to_mag == 0:
            continue
        to_dir = [to_tx/to_mag, to_ty/to_mag]
        
        # Calculate alignment scores - how well human input aligns with target direction
        align_human = (h_dir[0]*to_dir[0] + h_dir[1]*to_dir[1])
        align_recent = (recent_dir[0]*to_dir[0] + recent_dir[1]*to_dir[1])
        
        # Base score calculation (weighted combination of alignments)
        score = (align_human * 0.8) + (align_recent * 0.2)
        
        # Apply resistance penalty - make score threshold higher when close to current goal
        score_threshold = GOAL_SWITCH_THRESHOLD + resistance_factor
        
        # Only consider this a better target if score exceeds threshold by a margin
        if score > best_score and score > score_threshold:
            best_score = score
            best_idx = i
    
    # Add "persistence" - if we're changing targets, require a stronger signal
    if best_idx != current_target_idx:
        # Print for debugging purposes
        print(f"Target change attempted: {current_target_idx+1}->{best_idx+1}, score={best_score:.2f}, required>{GOAL_SWITCH_THRESHOLD + resistance_factor:.2f}")
    
    return best_idx

data_log = []
trial_start_time = time.time()
current_trajectory = []
trial_outcome = None

save_folder = "user_study_data"
os.makedirs(save_folder, exist_ok=True)

def get_save_filename(seed):
    session_timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
    return os.path.join(save_folder, f"data_log_seed{seed}_{session_timestamp}.json")

save_filename = None

def save_data_log(seed):
    if not save_filename:
        return
    with open(save_filename, "w") as f:
        json.dump(data_log, f, indent=4)
    print(f"Data log updated and saved to {save_filename} for seed={seed}")

def move_dot(human_input):
    global dot_pos, gamma, reached_goal, current_target_idx, USE_AI_CONTROL, trial_outcome

    if len(targets) == 0:
        return [0,0], [0,0], [0,0]

    h_dx, h_dy = human_input
    h_mag = math.hypot(h_dx, h_dy)
    h_dir = [h_dx / h_mag, h_dy / h_mag] if h_mag > 0 else [0, 0]

    if current_target_idx >= len(targets):
        current_target_idx = 0
    target_pos = targets[current_target_idx]

    w_dir = compute_perfect_direction(dot_pos, target_pos, obstacles)
    input_mag = min(max(h_mag / MAX_SPEED, 0), 1)
    step_size = MAX_SPEED * input_mag

    if USE_AI_CONTROL and h_mag > 0:
        dist_to_target = distance(dot_pos, target_pos)
        min_obs_distance = min(distance(dot_pos, obs) for obs in obstacles) if obstacles else float('inf')
        goal_threshold = GOAL_DETECTION_RADIUS * 3
        obs_threshold  = (OBSTACLE_RADIUS + DOT_RADIUS) * 3
        base_gamma     = 0.2

        if dist_to_target < goal_threshold:
            goal_factor = 1.0 - (dist_to_target / goal_threshold)
            base_gamma = max(base_gamma, 0.2 + 0.5 * goal_factor)
        if min_obs_distance < obs_threshold:
            # Increase AI intervention near obstacles
            obs_factor = 1.0 - (min_obs_distance / obs_threshold)
            base_gamma = max(base_gamma, 0.5 + 0.5 * obs_factor)  # Changed from 0.4 to 0.5
        if dist_to_target < goal_threshold and min_obs_distance < obs_threshold:
            base_gamma = max(base_gamma, 0.8)  # Changed from 0.7 to 0.8

        # Reduced noise for AI mode
        noise = random.uniform(-0.03, 0.03)  # Changed from ±0.05 to ±0.03
        final_gamma = base_gamma + noise
        gamma = max(0.0, min(1.0, final_gamma))

    else:
        # Manual or fixed gamma
        if gamma > 0.95:
            # First, determine what target the user is trying to reach
            user_intended_target = predict_human_target(human_input)
            
            # Calculate distance to current target
            dist_to_current = distance(dot_pos, targets[current_target_idx])
            
            # Define thresholds for goal switching restriction
            near_goal_threshold = GOAL_DETECTION_RADIUS * 5  # When we start restricting switches
            very_near_threshold = GOAL_DETECTION_RADIUS * 2.5  # When switching becomes nearly impossible
            
            # Determine if we should allow switching based on distance to current goal
            allow_switch = True
            switch_message = ""
            
            if dist_to_current < very_near_threshold:
                # Very close to goal - almost never allow switching (1% chance)
                allow_switch = random.random() < 0.01
                switch_message = "blocked (very close to current goal)"
            elif dist_to_current < near_goal_threshold:
                # Close to goal - rarely allow switching (linear decrease in probability)
                # From 50% at near_goal_threshold down to 1% at very_near_threshold
                switch_probability = 0.5 * (dist_to_current - very_near_threshold) / (near_goal_threshold - very_near_threshold)
                allow_switch = random.random() < switch_probability
                switch_message = f"restricted (close to current goal, {switch_probability:.2f} probability)"
            
            # Handle target switching based on restrictions
            if user_intended_target != current_target_idx and h_mag > 0.2:
                if allow_switch:
                    # Allow the switch
                    print(f"Gamma=1 mode following user's change from target {current_target_idx+1} to {user_intended_target+1}")
                    current_target_idx = user_intended_target
                else:
                    # Block the switch and inform about it
                    print(f"Gamma=1 mode blocking target change request: {current_target_idx+1}->{user_intended_target+1} {switch_message}")
            
            # Get the target position
            target_pos = targets[current_target_idx]
            
            # Calculate basic direction to target
            to_target_x = target_pos[0] - dot_pos[0]
            to_target_y = target_pos[1] - dot_pos[1]
            target_dist = math.hypot(to_target_x, to_target_y)
            
            if target_dist > 1e-6:
                to_target_x /= target_dist
                to_target_y /= target_dist
            
            # For smooth but unusual path selection, we'll use a modified approach that:
            # 1. Takes indirect routes to the target
            # 2. Maintains smooth trajectories
            # 3. Doesn't rely on obstacle attraction
            
            # Find the nearest obstacle for proper avoidance
            nearest_obstacle = None
            nearest_dist = float('inf')
            
            for obs in obstacles:
                obs_dist = distance(dot_pos, obs)
                if obs_dist < nearest_dist:
                    nearest_dist = obs_dist
                    nearest_obstacle = obs
            
            # Create smooth path variation using time-based sinusoidal offsets
            time_now = time.time()
            
            # Slow-changing directional bias (period of about 10 seconds)
            angle_offset = math.sin(time_now * 0.1) * (math.pi / 8)  # Max ±22.5 degree offset
            
            # Apply the angle offset to the target direction
            offset_angle = math.atan2(to_target_y, to_target_x) + angle_offset
            offset_dir_x = math.cos(offset_angle)
            offset_dir_y = math.sin(offset_angle)
            
            # Add a slight oscillating perpendicular component for more natural movement
            # This creates gentle curving paths rather than straight lines
            perp_x = -to_target_y
            perp_y = to_target_x
            perp_mag = math.hypot(perp_x, perp_y)
            
            if perp_mag > 1e-6:
                perp_x /= perp_mag
                perp_y /= perp_mag
                
            # Magnitude of perpendicular influence oscillates slowly
            perp_influence = math.sin(time_now * 0.3) * 0.2  # ±0.2 influence
            
            # Combine directions: main offset direction + perpendicular component
            final_dir_x = offset_dir_x + perp_x * perp_influence
            final_dir_y = offset_dir_y + perp_y * perp_influence
            
            # Add a small influence from user input
            user_influence = 0.1  # Small but noticeable influence from user
            if h_mag > 0.1:
                final_dir_x += h_dir[0] * user_influence
                final_dir_y += h_dir[1] * user_influence
            
            # Proper obstacle avoidance (no attraction, just avoidance)
            if nearest_obstacle and nearest_dist < OBSTACLE_RADIUS * 4:
                # Vector from dot to obstacle
                to_obs_x = nearest_obstacle[0] - dot_pos[0]
                to_obs_y = nearest_obstacle[1] - dot_pos[1]
                
                if nearest_dist > 1e-6:
                    # Normalize
                    to_obs_x /= nearest_dist
                    to_obs_y /= nearest_dist
                    
                    # Force pointing away from obstacle
                    avoid_x = -to_obs_x
                    avoid_y = -to_obs_y
                    
                    # Strength of avoidance (stronger when closer)
                    avoid_strength = 0.8 * (1.0 - min(1.0, nearest_dist / (OBSTACLE_RADIUS * 4)))
                    
                    # Add avoidance component
                    final_dir_x += avoid_x * avoid_strength
                    final_dir_y += avoid_y * avoid_strength
            
            # Normalize final direction
            final_mag = math.hypot(final_dir_x, final_dir_y)
            if final_mag > 1e-6:
                final_dir_x /= final_mag
                final_dir_y /= final_mag
            
            # Override the perfect direction with our smooth but unusual path
            w_dir = [final_dir_x, final_dir_y]
            
            # Modulate speed slightly for more natural movement
            # Varies between 85% and 115% of normal speed
            speed_factor = 1.0 + 0.15 * math.sin(time_now * 0.2)
            step_size *= speed_factor
    
    
        elif gamma < 0.05:
            print("Manual mode, gamma ~0 => dot is attracted to obstacles")
            ox, oy = 0.0, 0.0
            for obs in obstacles:
                dxo = obs[0] - dot_pos[0]
                dyo = obs[1] - dot_pos[1]
                dist_o = math.hypot(dxo, dyo)
                if dist_o > 1e-6:
                    ox += dxo / dist_o
                    oy += dyo / dist_o
            mo = math.hypot(ox, oy)
            if mo > 1e-6:
                ox /= mo
                oy /= mo
            w_dir = [ox, oy]

        elif abs(gamma - 0.5) < 0.06:
            print("Manual mode, gamma ~0.5 => partial obstacle attraction")
            # Add oscillation to gamma value
            time_factor = math.sin(time.time() * 2.0) * 0.2  # Oscillate between 0.3 and 0.7
            actual_gamma = 0.5 + time_factor
            
            ox, oy = 0.0, 0.0
            for obs in obstacles:
                dxo = obs[0] - dot_pos[0]
                dyo = obs[1] - dot_pos[1]
                dist_o = math.hypot(dxo, dyo)
                if dist_o > 1e-6:
                    ox += dxo / dist_o
                    oy += dyo / dist_o
            mo = math.hypot(ox, oy)
            if mo > 1e-6:
                ox /= mo
                oy /= mo
            blend_ratio = 0.3 + (0.2 * random.random())  # Add randomness to blending
            w_dir[0] = (1 - blend_ratio) * w_dir[0] + blend_ratio * ox
            w_dir[1] = (1 - blend_ratio) * w_dir[1] + blend_ratio * oy

    w_move_x = gamma * w_dir[0] * step_size
    w_move_y = gamma * w_dir[1] * step_size

    noise_x = np.random.normal(0, NOISE_MAGNITUDE)
    noise_y = np.random.normal(0, NOISE_MAGNITUDE)
    noisy_dx = h_dir[0] + noise_x
    noisy_dy = h_dir[1] + noise_y
    nm = math.hypot(noisy_dx, noisy_dy)
    if nm > 0:
        noisy_dx /= nm
        noisy_dy /= nm

    h_move_x = (1 - gamma) * noisy_dx * step_size
    h_move_y = (1 - gamma) * noisy_dy * step_size

    final_dx = w_move_x + h_move_x
    final_dy = w_move_y + h_move_y

    new_x = dot_pos[0] + final_dx
    new_y = dot_pos[1] + final_dy

    if not check_collision(dot_pos, [new_x, new_y]):
        dot_pos[0] = max(0, min(FULL_VIEW_SIZE[0], new_x))
        dot_pos[1] = max(0, min(FULL_VIEW_SIZE[1], new_y))

    if inside_obstacle(dot_pos):
        print("Collision with obstacle -> resetting!")
        trial_outcome = "collision"
        global failure_counter
        failure_counter += 1
        reset()
        return [0,0], [0,0], [0,0]

    final_mag = math.hypot(final_dx, final_dy)
    x_dir = [final_dx/final_mag, final_dy/final_mag] if final_mag > 0 else [0, 0]

    dist_to_goal = distance(dot_pos, target_pos)
    if dist_to_goal < GOAL_DETECTION_RADIUS:
        reached_goal = True
        trial_outcome = "success"
        if current_target_idx not in goal_counters:
            goal_counters[current_target_idx] = 1
        else:
            goal_counters[current_target_idx] += 1
        pygame.time.set_timer(pygame.USEREVENT, 1000)

    return h_dir, w_dir, x_dir

def reset():
    global dot_pos, reached_goal, current_target_idx, gamma
    global recent_positions, last_reset_time, trial_start_time, current_trajectory, trial_outcome
    global failure_counter
    
    if trial_start_time is not None and len(current_trajectory) > 0:
        trial_duration = time.time() - trial_start_time
        if reached_goal and 0 <= current_target_idx < len(targets):
            goal_reached = targets[current_target_idx]
        else:
            goal_reached = None
        mode = "AI" if USE_AI_CONTROL else "Manual"
        trial_timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        if trial_outcome == "manual_reset":
            failure_counter += 1

        data_log.append({
            "timestamp": trial_timestamp,
            "mode": mode,
            "trial_duration": trial_duration,
            "trial_outcome": trial_outcome if trial_outcome else "manual_reset",
            "goal_reached": goal_reached,
            "trajectory": current_trajectory.copy()
        })
        print(f"Trial recorded: {data_log[-1]}")
        save_data_log(current_seed)

    dot_pos = START_POS.copy()
    reached_goal = False
    current_target_idx = 0
    gamma = 0.95
    recent_positions.clear()
    last_reset_time = time.time()
    trial_start_time = time.time()
    current_trajectory.clear()
    trial_outcome = None
    pygame.time.set_timer(pygame.USEREVENT, 0)

def initialize_environment_fixed(seed):
    global obstacles, targets, goal_counters
    random.seed(seed)
    np.random.seed(seed)
    obstacles.clear()
    targets.clear()
    margin = 50 * SCALING_FACTOR
    min_goal_gap = 200 * SCALING_FACTOR
    N_GOALS = 8
    N_OBSTACLES = 5

    new_goals = []
    attempts = 0
    while len(new_goals) < N_GOALS and attempts < 1000:
        x = random.uniform(margin, FULL_VIEW_SIZE[0] - margin)
        y = random.uniform(margin, FULL_VIEW_SIZE[1] - margin)
        candidate = (x, y)
        if all(distance(candidate, g) >= min_goal_gap for g in new_goals):
            new_goals.append(candidate)
        attempts += 1
    targets.extend(new_goals)
    
    goal_counters = {i: 0 for i in range(len(targets))}

    new_obstacles = []
    if len(new_goals) > 1:
        obstacle_goals = random.sample(new_goals, k=min(min(N_GOALS-1, N_OBSTACLES), len(new_goals)-1))
    else:
        obstacle_goals = new_goals
    for goal in obstacle_goals:
        t = random.uniform(0.6, 0.8)
        base_point = (START_POS[0] + t * (goal[0] - START_POS[0]),
                      START_POS[1] + t * (goal[1] - START_POS[1]))
        vec = (goal[0] - START_POS[0], goal[1] - START_POS[1])
        vec_norm = math.hypot(vec[0], vec[1])
        if vec_norm < 1e-6:
            perp = (0, 0)
        else:
            perp = (-vec[1] / vec_norm, vec[0] / vec_norm)
        offset_mag = random.uniform(20 * SCALING_FACTOR, 40 * SCALING_FACTOR)
        offset = (perp[0] * offset_mag * random.choice([-1,1]),
                  perp[1] * offset_mag * random.choice([-1,1]))
        candidate = (base_point[0] + offset[0], base_point[1] + offset[1])
        candidate = (max(margin, min(candidate[0], FULL_VIEW_SIZE[0] - margin)),
                     max(margin, min(candidate[1], FULL_VIEW_SIZE[1] - margin)))
        valid = True
        if distance(candidate, START_POS) < (DOT_RADIUS + OBSTACLE_RADIUS + 10):
            valid = False
        if distance(candidate, goal) < (TARGET_RADIUS + OBSTACLE_RADIUS + 20):
            valid = False
        for obs in new_obstacles:
            if distance(candidate, obs) < (2 * OBSTACLE_RADIUS + 10):
                valid = False
        if valid:
            new_obstacles.append(candidate)
    obstacles.extend(new_obstacles)
    print(f"Environment initialized with fixed seed {seed}. #goals={len(targets)}, #obstacles={len(obstacles)}")


def draw_arrow(surface, color, start_pos, direction, length=ARROW_LENGTH):
    dx, dy = direction
    if dx == 0 and dy == 0:
        return
    mag = math.hypot(dx, dy)
    dx /= mag
    dy /= mag
    end_x = start_pos[0] + dx * length
    end_y = start_pos[1] + dy * length
    pygame.draw.line(surface, color, start_pos, (end_x, end_y), int(2 * SCALING_FACTOR))
    arrow_size = 7 * SCALING_FACTOR
    angle = math.atan2(dy, dx)
    arrow1_x = end_x - arrow_size * math.cos(angle + math.pi/6)
    arrow1_y = end_y - arrow_size * math.sin(angle + math.pi/6)
    arrow2_x = end_x - arrow_size * math.cos(angle - math.pi/6)
    arrow2_y = end_y - arrow_size * math.sin(angle - math.pi/6)
    pygame.draw.line(surface, color, (end_x, end_y), (arrow1_x, arrow1_y), int(2 * SCALING_FACTOR))
    pygame.draw.line(surface, color, (end_x, end_y), (arrow2_x, arrow2_y), int(2 * SCALING_FACTOR))

def render_full_view(surface, h_dir, w_dir, x_dir):
    """We read and modify current_target_idx, so we declare it global."""
    global current_target_idx

    surface.fill(WHITE)
    if ENABLE_OBSTACLES:
        for obstacle_pos in obstacles:
            pygame.draw.circle(surface, GRAY, (int(obstacle_pos[0]), int(obstacle_pos[1])), OBSTACLE_RADIUS)
    for i, target in enumerate(targets):
        pygame.draw.circle(surface, YELLOW, (int(target[0]), int(target[1])), TARGET_RADIUS)
        num_text = font.render(str(i + 1), True, BLACK)
        surface.blit(num_text, (target[0] - 5, target[1] - 12))

    # Now we can safely reference or modify current_target_idx
    if len(targets) > 0:
        if current_target_idx >= len(targets):
            current_target_idx = 0
        curr_t = targets[current_target_idx]
        pygame.draw.circle(surface, BLACK, (int(curr_t[0]), int(curr_t[1])),
                           TARGET_RADIUS + 2, int(2*SCALING_FACTOR))

    now = time.time()
    while len(recent_positions) > 0 and (now - recent_positions[0][2]) > GHOST_TRAIL_DURATION:
        recent_positions.pop(0)
    if len(recent_positions) > 1:
        for idx in range(len(recent_positions) - 1):
            x1, y1, t1 = recent_positions[idx]
            x2, y2, t2 = recent_positions[idx+1]
            pygame.draw.line(surface, (200, 200, 200), (x1, y1), (x2, y2), 2)

    pygame.draw.circle(surface, BLACK, (int(dot_pos[0]), int(dot_pos[1])),
                       DOT_RADIUS, int(2*SCALING_FACTOR))

    if h_dir != [0,0]:
        draw_arrow(surface, BLUE, (int(dot_pos[0]), int(dot_pos[1])), h_dir, ARROW_LENGTH)
    if w_dir != [0,0]:
        draw_arrow(surface, GREEN, (int(dot_pos[0]), int(dot_pos[1])), w_dir, ARROW_LENGTH)
    if x_dir != [0,0]:
        draw_arrow(surface, RED, (int(dot_pos[0]), int(dot_pos[1])), x_dir, ARROW_LENGTH)

    g_txt = font.render(f"Gamma: {gamma:.2f}", True, FONT_COLOR)
    surface.blit(g_txt, (10, 10))
    form_txt = font.render(f"Movement = {gamma:.2f}W + {1-gamma:.2f}H", True, FONT_COLOR)
    surface.blit(form_txt, (10, 40))
    noise_txt = font.render(f"Noise σ: {NOISE_MAGNITUDE:.2f}", True, FONT_COLOR)
    surface.blit(noise_txt, (10, 100))
    instr_txt = font.render("L2/R2: gamma, [/]: noise, R: reset", True, FONT_COLOR)
    surface.blit(instr_txt, (10, 70))
    mode_txt = font.render(f"Control: {'AI' if USE_AI_CONTROL else 'Manual'} (Y to toggle)", True, FONT_COLOR)
    surface.blit(mode_txt, (10, 160))

    force_mode_txt = font.render(f"Input: {'Force Sensor' if USE_FORCE_SENSOR else 'Joystick/Keyboard'} (F to toggle)", True, FONT_COLOR)
    surface.blit(force_mode_txt, (10, 190))
    if not FORCE_SENSOR_AVAILABLE:
        no_sensor_txt = font.render("Force sensor not available!", True, RED)
        surface.blit(no_sensor_txt, (10, 220))

    elapsed_time = time.time() - last_reset_time
    timer_text = font.render(f"Time: {elapsed_time:.1f}s", True, FONT_COLOR)
    surface.blit(timer_text, (10, 130))
    if reached_goal:
        r_txt = font.render(f"Goal Reached in {elapsed_time:.1f}s! Auto-resetting...", True, FONT_COLOR)
        surface.blit(r_txt, (150, 110))
    seed_txt = font.render(f"Scenario Seed: {current_seed}", True, FONT_COLOR)
    surface.blit(seed_txt, (10, 250))

    legend_y = FULL_VIEW_SIZE[1] - int(100 * SCALING_FACTOR)
    legend_spacing = int(30 * SCALING_FACTOR)
    legend_items = [
        ("Green Arrow: Perfect Path (W)", GREEN),
        ("Blue Arrow: Human Movement (H)", BLUE),
        ("Red Arrow: Dot's Movement", RED),
        ("Gray line: Movement History", (200, 200, 200))
    ]
    for i, (lbl, color) in enumerate(legend_items):
        label = font.render(lbl, True, color)
        surface.blit(label, (10, legend_y + i*legend_spacing))

    counter_x = FULL_VIEW_SIZE[0] - 200
    counter_y = 10
    counter_spacing = int(18 * SCALING_FACTOR)
    counter_header = font.render("Results:", True, BLACK)
    surface.blit(counter_header, (counter_x, counter_y))
    counter_y += counter_spacing
    for i in range(len(targets)):
        count = goal_counters.get(i, 0)
        goal_txt = font.render(f"Goal {i+1}: {count}", True, GREEN)
        surface.blit(goal_txt, (counter_x, counter_y))
        counter_y += counter_spacing
    failure_txt = font.render(f"Failures: {failure_counter}", True, RED)
    surface.blit(failure_txt, (counter_x, counter_y))

def render_red_only(surface, x_dir):
    global current_target_idx

    surface.fill(WHITE)
    if ENABLE_OBSTACLES:
        for obstacle_pos in obstacles:
            pygame.draw.circle(surface, GRAY, (int(obstacle_pos[0]), int(obstacle_pos[1])), OBSTACLE_RADIUS)
    for i, target in enumerate(targets):
        color = GREEN if i == current_target_idx else RED
        pygame.draw.circle(surface, color, (int(target[0]), int(target[1])), TARGET_RADIUS)
        if i == current_target_idx:
            pygame.draw.circle(surface, BLACK, (int(target[0]), int(target[1])),
                               TARGET_RADIUS + 2, int(2 * SCALING_FACTOR))
        num_text = font.render(str(i + 1), True, BLACK)
        surface.blit(num_text, (target[0] - 5, target[1] - 12))

    pygame.draw.circle(surface, BLACK, (int(dot_pos[0]), int(dot_pos[1])),
                       DOT_RADIUS, int(2 * SCALING_FACTOR))

    if x_dir != [0,0]:
        draw_arrow(surface, RED, (int(dot_pos[0]), int(dot_pos[1])), x_dir, ARROW_LENGTH)

    elapsed_time = time.time() - last_reset_time
    timer_text = font.render(f"Time: {elapsed_time:.1f}s", True, BLACK)
    surface.blit(timer_text, (10, 10))

    if USE_FORCE_SENSOR:
        mode_text = font.render("Force Sensor Mode", True, BLACK)
        surface.blit(mode_text, (10, 40))

    if reached_goal:
        completion_text = font.render("Goal Reached!", True, BLACK)
        text_rect = completion_text.get_rect(center=(RED_ONLY_SIZE[0]/2, 40))
        surface.blit(completion_text, text_rect)

    counter_x = RED_ONLY_SIZE[0] - 200
    counter_y = 10
    counter_spacing = int(18 * SCALING_FACTOR)
    counter_header = font.render("Counter:", True, BLACK)
    surface.blit(counter_header, (counter_x, counter_y))
    counter_y += counter_spacing
    for i in range(len(targets)):
        count = goal_counters.get(i, 0)
        goal_txt = font.render(f"Goal {i+1}: {count}", True, GREEN)
        surface.blit(goal_txt, (counter_x, counter_y))
        counter_y += counter_spacing
    failure_txt = font.render(f"Failures: {failure_counter}", True, RED)
    surface.blit(failure_txt, (counter_x, counter_y))

# -----------------------------------------------------------------------------
# FIX: Remove the lines that directly set the next seed & reinitialize here,
#      and simply end the current environment so the outer loop picks up
#      the next seed. This prevents the duplication of seeds.
# -----------------------------------------------------------------------------
def skip_to_next_environment():
    global data_log, running, save_filename, current_seed, trial_start_time, failure_counter
    global gamma_mode_index, gamma_modes, current_gamma_mode

    # Save data for the current seed
    save_data_log(current_seed)

    # Figure out if we are at the last seed
    current_index = SCENARIO_SEEDS.index(current_seed)
    if current_index < len(SCENARIO_SEEDS) - 1:
        print("Skipping to the next environment (same gamma mode).")
        # Removed the lines that changed current_seed & re-initialized environment
        # Just stop the current loop so the outer for-loop advances to the next seed:
        running = False
    else:
        # Already at the last seed -> skip to the next gamma mode
        print("Already at the last environment seed. Skipping to next gamma mode.")
        running = False
        # Set a flag so we skip any remaining seeds in this gamma mode
        if 'skip_remaining_seeds' not in globals():
            global skip_remaining_seeds
        skip_remaining_seeds = True

###############################################################################
# MAIN EXPERIMENT LOOP
###############################################################################

gamma_modes = [0.0, 0.5, 1.0, "manual", "ai"]
current_seed = None
save_filename = None
skip_remaining_seeds = False

for gamma_mode in gamma_modes:
    current_gamma_mode = gamma_mode
    print(f"\n===== STARTING GAMMA MODE = {gamma_mode} =====\n")
    skip_remaining_seeds = False  # Reset at the start of each gamma mode

    for s_index, s in enumerate(SCENARIO_SEEDS):

        if skip_remaining_seeds and s_index > 0:
            print(f"Skipping seed {s} to move to next gamma mode")
            continue

        current_seed = s
        data_log = []
        save_filename = get_save_filename(s)

        initialize_environment_fixed(s)

        global trial_start_time, failure_counter
        trial_start_time = time.time()
        failure_counter = 0
        reset()

        running = True
        clock = pygame.time.Clock()

        while running:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                    break
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_f:
                        if not FORCE_SENSOR_AVAILABLE and not USE_FORCE_SENSOR:
                            print("Force sensor not available!")
                        else:
                            USE_FORCE_SENSOR = not USE_FORCE_SENSOR
                            print("Force sensor mode:", USE_FORCE_SENSOR)
                    if event.key == pygame.K_LEFTBRACKET:
                        NOISE_MAGNITUDE = max(MIN_NOISE, NOISE_MAGNITUDE - NOISE_STEP)
                    elif event.key == pygame.K_RIGHTBRACKET:
                        NOISE_MAGNITUDE = min(MAX_NOISE, NOISE_MAGNITUDE + NOISE_STEP)
                    if event.key == pygame.K_r:
                        trial_outcome = "manual_reset"
                        reset()
                    
                    if event.key == pygame.K_n:
                        skip_to_next_environment()
                        print("N key pressed: Skipping to next environment (same gamma mode)")

                    if event.key == pygame.K_SPACE and USE_FORCE_SENSOR:
                        USE_AI_CONTROL = not USE_AI_CONTROL
                        print(f"{'AI' if USE_AI_CONTROL else 'Manual'} control enabled (Space Key)")

                if joystick and event.type == pygame.JOYBUTTONDOWN:
                    if event.button == 2:
                        trial_outcome = "manual_reset"
                        reset()
                    if event.button == 3:
                        USE_AI_CONTROL = not USE_AI_CONTROL
                        print(f"{'AI' if USE_AI_CONTROL else 'Manual'} control enabled")
                    if event.button == 4:  # Add L1 for skipping to next environment
                        skip_to_next_environment()
                        print("L1 pressed: Skipping to next environment (same gamma mode)")

                if event.type == pygame.USEREVENT:
                    if not reached_goal:
                        trial_outcome = "timeout"
                    reset()

            if not running:
                break

            # check if we have 3 successes for each goal
            if len(targets) > 0:
                all_goals_3x = all(count >= 1 for count in goal_counters.values())
                if all_goals_3x:
                    print("All goals reached at least 3 times. Moving on to next environment seed...")
                    running = False
                    continue
            else:
                # If no targets at all, skip this environment
                print("No targets in this environment. Skipping...")
                running = False
                continue

            if not reached_goal:
                # Decide if we fix gamma or use AI or manual
                if isinstance(gamma_mode, float):
                    gamma = gamma_mode
                    USE_AI_CONTROL = False
                elif gamma_mode == "ai":
                    USE_AI_CONTROL = True
                else:
                    # "manual"
                    USE_AI_CONTROL = False

                if USE_FORCE_SENSOR and FORCE_SENSOR_AVAILABLE:
                    dx, dy = force_sensor_input
                else:
                    if USE_FORCE_SENSOR and not FORCE_SENSOR_AVAILABLE:
                        USE_FORCE_SENSOR = False

                    dx, dy = 0.0, 0.0
                    keys = pygame.key.get_pressed()
                    if keys[pygame.K_LEFT]:
                        dx -= 1
                    if keys[pygame.K_RIGHT]:
                        dx += 1
                    if keys[pygame.K_UP]:
                        dy -= 1
                    if keys[pygame.K_DOWN]:
                        dy += 1

                    if joystick:
                        axis_0 = joystick.get_axis(0)
                        axis_1 = joystick.get_axis(1)
                        deadzone = 0.1
                        if abs(axis_0) > deadzone or abs(axis_1) > deadzone:
                            dx = axis_0
                            dy = axis_1
                        else:
                            dx, dy = 0.0, 0.0
                        l2_val = joystick.get_axis(AXIS_L2)
                        r2_val = joystick.get_axis(AXIS_R2)
                        if gamma_mode == "manual":
                            if l2_val > 0.1:
                                gamma = max(0.0, gamma - 0.01)
                            if r2_val > 0.1:
                                gamma = min(1.0, gamma + 0.01)

                if abs(dx) < 0.1 and abs(dy) < 0.1:
                    dx, dy = 0.0, 0.0

                if not USE_FORCE_SENSOR:
                    dx *= MAX_SPEED
                    dy *= MAX_SPEED

                human_input = [dx, dy]
                proposed_idx = predict_human_target(human_input)
                current_target_idx = proposed_idx if proposed_idx < len(targets) else 0

                h_dir, w_dir, x_dir = move_dot(human_input)
                if not reached_goal:
                    recent_positions.append((dot_pos[0], dot_pos[1], time.time()))
                    current_trajectory.append((dot_pos[0], dot_pos[1], gamma))
            else:
                h_dir, w_dir, x_dir = [0,0], [0,0], [0,0]

            render_full_view(surface_full, h_dir, w_dir, x_dir)
            render_red_only(surface_red_only, x_dir)

            tex1 = surface_to_texture(renderer1, surface_full)
            tex2 = surface_to_texture(renderer2, surface_red_only)

            renderer1.clear()
            tex1.draw(dstrect=(0, 0, FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1]))
            renderer1.present()

            renderer2.clear()
            tex2.draw(dstrect=(0, 0, RED_ONLY_SIZE[0], RED_ONLY_SIZE[1]))
            renderer2.present()

            clock.tick(60)

        save_data_log(s)
        print(f"Finished environment seed: {s} (Gamma mode={gamma_mode})")

if ser is not None:
    ser.close()

pygame.quit()
print("All seeds completed. Exiting.")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Error: Could not open serial port: could not open port 'COM5': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)
# Force sensor not available. Using keyboard/joystick controls only.
# Joystick initialized: DualSense Wireless Controller
#
# ===== STARTING GAMMA MODE = 0.0 =====
#
# Environment initialized with fixed seed 0. #goals=5, #obstacles=3
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 1->4, score=0.77, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.75, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.77, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.73, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.72, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.71, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.72, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.78, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.74, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.77, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.75, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.75, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.77, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.71, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.64, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.80, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.62, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.80, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.58, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.80, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.56, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.80, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.62, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.80, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.69, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.77, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.71, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.76, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.72, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.74, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.76, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.67, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.63, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.62, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.61, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.62, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.62, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.62, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.06
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.62, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.10
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.61, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.08
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.59, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.06
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.60, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.09
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.57, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.10
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.51, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.11
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.46, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.11
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.44, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.14
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.42, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.11
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.40, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.13
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.39, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.13
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.37, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.13
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.34, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.15
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.34, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.13
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.32, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.13
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.29, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.14
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.33, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.15
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.30, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.14
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.27, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.80, required>0.11
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.25, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.79, required>0.11
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->3, score=0.11, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 3->4, score=0.76, required>0.13
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->2, score=0.17, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 2->4, score=0.43, required>0.16
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Target change attempted: 4->2, score=0.53, required>0.05
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Data log updated and saved to user_study_data\data_log_seed0_20250320_154335.json for seed=0
# Skipping to the next environment (same gamma mode).
# N key pressed: Skipping to next environment (same gamma mode)
# Data log updated and saved to user_study_data\data_log_seed0_20250320_154335.json for seed=0
# Finished environment seed: 0 (Gamma mode=0.0)
# Environment initialized with fixed seed 2. #goals=7, #obstacles=5
# Trial recorded: {'timestamp': '2025-03-20 15:43:38', 'mode': 'Manual', 'trial_duration': 0.0, 'trial_outcome': 'manual_reset', 'goal_reached': None, 'trajectory': [(600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.6267865896787, 400.67136450827553, 0.0), (600.923147227342, 398.8934389797175, 0.0), (599.2162989171841, 396.2533953814182, 0.0), (595.1412537288663, 395.9588202732131, 0.0), (599.1316359238001, 398.97160137019904, 0.0), (602.6628129309569, 395.4317159279669, 0.0), (597.8147526000622, 394.2084780001679, 0.0), (594.4376289327353, 397.8956226590578, 0.0), (599.4370955165657, 397.9686560566405, 0.0), (594.5367369236512, 396.97543621146554, 0.0), (590.3827269315126, 399.75827666417075, 0.0), (585.4002893273303, 400.176983626652, 0.0), (582.6278520346854, 404.33794402761134, 0.0), (577.6631126223456, 403.745185588144, 0.0), (572.7595438299636, 402.76793787216917, 0.0), (568.5086281897001, 405.40037328816, 0.0), (564.2851146356977, 408.07655214226486, 0.0), (566.9209999560776, 403.8277748384037, 0.0), (567.4291668158427, 408.44062405109355, 0.0), (563.0658803907471, 407.73631204442694, 0.0), (558.6811886451891, 407.2390422641595, 0.0), (556.9037529006613, 403.13021350409497, 0.0), (559.3896027713577, 407.04076865948184, 0.0), (556.1670321205113, 403.56199460439643, 0.0), (559.1832760340615, 399.7602480613132, 0.0), (554.4518906930556, 398.14346336478917, 0.0), (556.3142150875019, 402.78369480835426, 0.0), (552.9432215508108, 399.09094480658234, 0.0), (548.3354681469609, 401.0322352457772, 0.0), (543.439964097416, 400.01535762241747, 0.0), (538.4844723258093, 400.6810161696758, 0.0), (533.5481047011442, 401.4761731819432, 0.0), (536.2035267553166, 405.7127677712584, 0.0), (531.5029763774457, 407.41712282379257, 0.0), (531.5333129783555, 402.417214855575, 0.0), (536.3159373834922, 403.87546853700076, 0.0), (531.5364014493697, 402.4071238041698, 0.0), (535.6951732153121, 399.6314045462476,  ...
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154338.json for seed=2
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154338.json for seed=2
# Skipping to the next environment (same gamma mode).
# N key pressed: Skipping to next environment (same gamma mode)
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154338.json for seed=2
# Finished environment seed: 2 (Gamma mode=0.0)
# Environment initialized with fixed seed 58. #goals=6, #obstacles=5
# Trial recorded: {'timestamp': '2025-03-20 15:43:38', 'mode': 'Manual', 'trial_duration': 0.0, 'trial_outcome': 'manual_reset', 'goal_reached': None, 'trajectory': [(600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0)]}
# Data log updated and saved to user_study_data\data_log_seed58_20250320_154338.json for seed=58
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Manual mode, gamma ~0 => dot is attracted to obstacles
# Data log updated and saved to user_study_data\data_log_seed58_20250320_154338.json for seed=58
# Already at the last environment seed. Skipping to next gamma mode.
# N key pressed: Skipping to next environment (same gamma mode)
# Data log updated and saved to user_study_data\data_log_seed58_20250320_154338.json for seed=58
# Finished environment seed: 58 (Gamma mode=0.0)
#
# ===== STARTING GAMMA MODE = 0.5 =====
#
# Environment initialized with fixed seed 0. #goals=5, #obstacles=3
# Trial recorded: {'timestamp': '2025-03-20 15:43:38', 'mode': 'Manual', 'trial_duration': 0.0, 'trial_outcome': 'manual_reset', 'goal_reached': None, 'trajectory': [(600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0), (600.0, 400.0, 0.0)]}
# Data log updated and saved to user_study_data\data_log_seed0_20250320_154338.json for seed=0
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Data log updated and saved to user_study_data\data_log_seed0_20250320_154338.json for seed=0
# Skipping to the next environment (same gamma mode).
# N key pressed: Skipping to next environment (same gamma mode)
# Data log updated and saved to user_study_data\data_log_seed0_20250320_154338.json for seed=0
# Finished environment seed: 0 (Gamma mode=0.5)
# Environment initialized with fixed seed 2. #goals=7, #obstacles=5
# Trial recorded: {'timestamp': '2025-03-20 15:43:39', 'mode': 'Manual', 'trial_duration': 0.0, 'trial_outcome': 'manual_reset', 'goal_reached': None, 'trajectory': [(600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5)]}
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154339.json for seed=2
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154339.json for seed=2
# Skipping to the next environment (same gamma mode).
# N key pressed: Skipping to next environment (same gamma mode)
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154339.json for seed=2
# Finished environment seed: 2 (Gamma mode=0.5)
# Environment initialized with fixed seed 58. #goals=6, #obstacles=5
# Trial recorded: {'timestamp': '2025-03-20 15:43:39', 'mode': 'Manual', 'trial_duration': 0.0, 'trial_outcome': 'manual_reset', 'goal_reached': None, 'trajectory': [(600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5)]}
# Data log updated and saved to user_study_data\data_log_seed58_20250320_154339.json for seed=58
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Manual mode, gamma ~0.5 => partial obstacle attraction
# Data log updated and saved to user_study_data\data_log_seed58_20250320_154339.json for seed=58
# Already at the last environment seed. Skipping to next gamma mode.
# N key pressed: Skipping to next environment (same gamma mode)
# Data log updated and saved to user_study_data\data_log_seed58_20250320_154339.json for seed=58
# Finished environment seed: 58 (Gamma mode=0.5)
#
# ===== STARTING GAMMA MODE = 1.0 =====
#
# Environment initialized with fixed seed 0. #goals=5, #obstacles=3
# Trial recorded: {'timestamp': '2025-03-20 15:43:39', 'mode': 'Manual', 'trial_duration': 0.0, 'trial_outcome': 'manual_reset', 'goal_reached': None, 'trajectory': [(600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5), (600.0, 400.0, 0.5)]}
# Data log updated and saved to user_study_data\data_log_seed0_20250320_154339.json for seed=0
# Target change attempted: 1->4, score=0.78, required>0.05
# Target change attempted: 4->3, score=0.74, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.05
# Target change attempted: 4->3, score=0.71, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.69, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.05
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.05
# Target change attempted: 4->3, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.06
# Target change attempted: 4->3, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.07
# Target change attempted: 4->3, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.09
# Target change attempted: 4->3, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.10
# Target change attempted: 4->3, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.12
# Target change attempted: 4->3, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.14
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.15
# Target change attempted: 4->3, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.17
# Target change attempted: 4->3, score=0.65, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.18
# Target change attempted: 4->3, score=0.64, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.20
# Target change attempted: 4->3, score=0.61, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.22
# Target change attempted: 4->3, score=0.57, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.23
# Target change attempted: 4->3, score=0.52, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.25
# Target change attempted: 4->3, score=0.47, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.78, required>0.27
# Target change attempted: 4->3, score=0.41, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.77, required>0.28
# Target change attempted: 4->3, score=0.36, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.75, required>0.30
# Target change attempted: 4->2, score=0.34, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.74, required>0.05
# Target change attempted: 4->2, score=0.36, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.72, required>0.05
# Target change attempted: 4->2, score=0.38, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.70, required>0.05
# Target change attempted: 4->2, score=0.40, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.69, required>0.05
# Target change attempted: 4->2, score=0.41, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.69, required>0.05
# Target change attempted: 4->2, score=0.41, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.68, required>0.05
# Target change attempted: 4->2, score=0.40, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.68, required>0.05
# Target change attempted: 4->2, score=0.40, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.67, required>0.05
# Target change attempted: 4->2, score=0.40, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.67, required>0.05
# Target change attempted: 4->2, score=0.40, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.65, required>0.06
# Target change attempted: 4->2, score=0.41, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.62, required>0.07
# Target change attempted: 4->2, score=0.45, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.58, required>0.09
# Target change attempted: 4->2, score=0.48, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.57, required>0.10
# Target change attempted: 4->2, score=0.49, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.56, required>0.12
# Target change attempted: 4->2, score=0.48, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.56, required>0.14
# Target change attempted: 4->2, score=0.48, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.56, required>0.15
# Target change attempted: 4->2, score=0.46, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.60, required>0.17
# Target change attempted: 4->2, score=0.41, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.66, required>0.19
# Target change attempted: 4->2, score=0.31, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.72, required>0.20
# Target change attempted: 4->2, score=0.18, required>0.05
# Gamma=1 mode following user's change from target 4 to 2
# Target change attempted: 2->4, score=0.75, required>0.22
# Target change attempted: 4->3, score=0.18, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.77, required>0.06
# Target change attempted: 4->3, score=0.24, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.08
# Target change attempted: 4->3, score=0.30, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.79, required>0.09
# Target change attempted: 4->3, score=0.33, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.11
# Target change attempted: 4->3, score=0.36, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.13
# Target change attempted: 4->3, score=0.37, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.14
# Target change attempted: 4->3, score=0.37, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.16
# Target change attempted: 4->3, score=0.37, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.18
# Target change attempted: 4->3, score=0.37, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.19
# Target change attempted: 4->3, score=0.37, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.21
# Target change attempted: 4->3, score=0.37, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.23
# Target change attempted: 4->3, score=0.36, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.24
# Target change attempted: 4->3, score=0.36, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.26
# Target change attempted: 4->3, score=0.36, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.28
# Target change attempted: 4->3, score=0.34, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.29
# Target change attempted: 4->3, score=0.28, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.31
# Target change attempted: 4->3, score=0.23, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.33
# Target change attempted: 4->3, score=0.20, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.34
# Target change attempted: 4->3, score=0.19, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.36
# Target change attempted: 4->3, score=0.18, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.38
# Target change attempted: 4->3, score=0.17, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.39
# Target change attempted: 4->3, score=0.16, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.41
# Target change attempted: 4->3, score=0.15, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.43
# Target change attempted: 4->3, score=0.15, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# Target change attempted: 3->4, score=0.80, required>0.44
# Target change attempted: 4->3, score=0.14, required>0.05
# Gamma=1 mode following user's change from target 4 to 3
# ...
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.72, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.72, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.71, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.71, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.71, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.70, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.70, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.70, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.69, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.69, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.68, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.68, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.68, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.67, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.67, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.66, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.66, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.65, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.65, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.64, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.64, required>0.05
# Target change attempted: 2->5, score=0.67, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.63, required>0.05
# Target change attempted: 2->5, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.63, required>0.05
# Target change attempted: 2->5, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.62, required>0.05
# Target change attempted: 2->5, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.62, required>0.05
# Target change attempted: 2->5, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.61, required>0.05
# Target change attempted: 2->5, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.60, required>0.05
# Target change attempted: 2->5, score=0.66, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.57, required>0.05
# Target change attempted: 2->5, score=0.68, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.50, required>0.05
# Target change attempted: 2->5, score=0.72, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.40, required>0.05
# Target change attempted: 2->5, score=0.76, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->2, score=0.09, required>0.05
# Target change attempted: 2->5, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 2 to 5
# Target change attempted: 5->4, score=0.72, required>0.05
# Target change attempted: 4->1, score=0.32, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.64, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->7, score=0.64, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.63, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->4, score=0.63, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.65, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.65, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.65, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.64, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.62, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.62, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.62, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.61, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.60, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->4, score=0.59, required>0.05
# Target change attempted: 4->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 4 to 1
# Target change attempted: 1->7, score=0.58, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.59, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.60, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.60, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.59, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.59, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.59, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.59, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.59, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.60, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.61, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.62, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.64, required>0.05
# Target change attempted: 7->1, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.66, required>0.05
# Target change attempted: 7->1, score=0.79, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.68, required>0.05
# Target change attempted: 7->1, score=0.78, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.70, required>0.05
# Target change attempted: 7->1, score=0.77, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.74, required>0.05
# Target change attempted: 7->1, score=0.75, required>0.05
# Gamma=1 mode following user's change from target 7 to 1
# Target change attempted: 1->7, score=0.76, required>0.05
# Target change attempted: 7->3, score=0.72, required>0.05
# Gamma=1 mode following user's change from target 7 to 3
# Target change attempted: 3->7, score=0.78, required>0.05
# Target change attempted: 7->3, score=0.75, required>0.05
# Gamma=1 mode following user's change from target 7 to 3
# Target change attempted: 3->7, score=0.80, required>0.05
# Target change attempted: 7->3, score=0.79, required>0.05
# Gamma=1 mode following user's change from target 7 to 3
# Target change attempted: 3->7, score=0.78, required>0.05
# Target change attempted: 7->3, score=0.80, required>0.05
# Gamma=1 mode following user's change from target 7 to 3
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154354.json for seed=2
# Skipping to the next environment (same gamma mode).
# N key pressed: Skipping to next environment (same gamma mode)
# Data log updated and saved to user_study_data\data_log_seed2_20250320_154354.json for seed=2
# Finished environment seed: 2 (Gamma mode=1.0)
# Environment initialized with fixed seed 58. #goals=6, #obstacles=5
# Trial recorded: {'timestamp': '2025-03-20 15:44:13', 'mode': 'Manual', 'trial_duration': 0.0, 'trial_outcome': 'manual_reset', 'goal_reached': None, 'trajectory': [(595.2807693393137, 400.4168578584824, 1.0), (590.5610620787809, 400.84612932574765, 1.0), (585.840368363608, 401.28992939218335, 1.0), (581.118684993255, 401.7485046493837, 1.0), (576.3960970155513, 402.22176823641814, 1.0), (571.672668646859, 402.70971305947376, 1.0), (566.9483921303743, 403.21262004372113, 1.0), (562.223311367688, 403.7305711650922, 1.0), (557.4975526467312, 404.2633121386472, 1.0), (552.7711690014618, 404.8108874414746, 1.0), (548.044158615876, 405.3735773364165, 1.0), (543.3165877144587, 405.9513790182117, 1.0), (538.5885009229618, 406.5443856753619, 1.0), (533.8599144550657, 407.152822097688, 1.0), (529.130887952943, 407.7767253134093, 1.0), (524.4015493972032, 408.4158185974152, 1.0), (519.6719559367755, 409.0701494240512, 1.0), (514.9421360376488, 409.73990626946835, 1.0), (510.21212010879356, 410.425277466123, 1.0), (505.48196762487953, 411.1263157868348, 1.0), (500.7517596193857, 411.84296852807233, 1.0), (496.0215178309294, 412.5754897000549, 1.0), (491.29132266548237, 413.32383638694085, 1.0), (486.56116930172203, 414.0884257277954, 1.0), (481.83110357510736, 414.8694171950643, 1.0), (477.10118081606254, 415.6669263460154, 1.0), (472.37162289708215, 416.48011639150576, 1.0), (467.64238850388006, 417.30966434414864, 1.0), (462.91354638078985, 418.15561964113, 1.0), (458.1851521223866, 419.0181186260567, 1.0), (453.45728944410564, 419.89712957747, 1.0), (448.7301004794028, 420.7922435616519, 1.0), (444.0036023411779, 421.7038663635483, 1.0), (439.27787227609167, 422.6320190756653, 1.0), (434.55297373858525, 423.576825453677, 1.0), (429.82899317516984, 424.5382552917166, 1.0), (425.1060329453496, 425.51616353146926, 1.0), (420.38411931403806, 426.5109852228468, 1.0), (415.6633468301934, 427.5226496874989, 1.0), (410.9437500048548, 428.5515778732884, 1.0), (406.2254822283668, 429.59722466936336, 1.0), (401.50867013035275, 430.6592501364819, 1.0), (396.79327462085126, 431.7387921881782, 1.0), (392.07939657357036, 432.83577440520224, 1.0), (387.3671230919898, 433.9502576376311, 1.0), (382.6565191805946, 435.08254270128145, 1.0), (377.94768850966943, 436.2325596995237, 1.0), (373.2407231155392, 437.4003747899309, 1.0), (368.53571734681645, 438.5860476171951, 1.0), (363.8327497496333, 439.78985265830914, 1.0), (359.1856874890018, 441.0177373201288, 1.0), (355.08407142979786, 442.15690108162914, 1.0), (351.87198568769526, 443.10421736133065, 1.0), (350.1337770501267, 443.6914019034297, 1.0), (350.65762400556207, 443.97213397906836, 1.0), (350.65762400556207, 443.97213397906836, 1.0), (350.65762400556207, 443.97213397906836, 1.0), (351.2816051500171, 444.2369629797761, 1.0), (352.18692972142446, 444.61197744369804, 1.0), (353.5500018228034, 445.17897055940324, 1.0), (355.54040188508344, 446.01214597214647, 1.0), (358.02959638723206, 447.0608417111167, 1.0), (361.0274409863476, 448.3187804368216, 1.0), (364.53556799341106, 449.78391400222233, 1.0), (368.3839430840943, 451.3794406067225, 1.0), (372.40308565703634, 453.02947189797106, 1.0), (376.47304167381753, 454.69372547640126, 1.0), (380.51486036700953, 456.3391819890492, 1.0), (384.59503799428154, 457.99005045532215, 1.0), (388.680367785992, 459.63415432923614, 1.0), (392.8043365251243, 461.2833541221165, 1.0), (397.0676200654542, 462.9736553189468, 1.0), (401.57326319672427, 464.7404680699854, 1.0), (406.1546082834221, 466.5171261730174, 1.0), (410.74133610311895, 468.2869546021831, 1.0), (415.3335440294931, 470.04936982322556, 1.0), (419.9313541641438, 471.8042117389393, 1.0), (424.5347199888754, 473.5515237210319, 1.0), (429.1434027044576, 475.29158408640126, 1.0), (433.76085315033345, 477.01538453114483, 1.0), (438.3871187310914, 478.72273767871224, 1.0), (443.0208211379849, 480.416891998539, 1.0), (447.6643751322215, 482.09139622485526, 1.0), (452.3209097667662, 483.7369083610757, 1.0), (45 ...
# Data log updated and saved to user_study_data\data_log_seed58_20250320_154413.json for seed=58
