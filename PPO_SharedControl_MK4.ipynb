# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.utils import set_random_seed
import torch.multiprocessing as mp

import pygame
import matplotlib.pyplot as plt
import time

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Constants
FULL_VIEW_SIZE = (1200, 800)
MAX_SPEED = 3
DOT_RADIUS = 30
TARGET_RADIUS = 10
GOAL_DETECTION_RADIUS = DOT_RADIUS + TARGET_RADIUS
START_POS = [FULL_VIEW_SIZE[0] // 2, FULL_VIEW_SIZE[1] // 2]
NOISE_MAGNITUDE = 0.5

# Colors
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)
GREEN = (0, 200, 0)
BLUE = (0, 0, 255)
YELLOW = (255, 255, 0)

class OptimizedCustomFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 128):
        super().__init__(observation_space, features_dim)
        
        n_input = int(np.prod(observation_space.shape))
        
        self.network = nn.Sequential(
            nn.Linear(n_input, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Linear(256, features_dim),
            nn.ReLU(),
            nn.BatchNorm1d(features_dim)
        )
        
        # Initialize weights properly
        for m in self.network.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0)
                
    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.network(observations)

class MetricsCallback(BaseCallback):
    """
    Modified callback that tracks:
      - Episode total rewards
      - Average gamma per episode
      - Actor loss and critic loss from SB3 logger
    Then plots:
      1. Average reward per episode
      2. Average gamma per episode
      3. Actor & Critic loss
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_gammas = []
        self.current_episode_gammas = []
        self.total_reward = 0
        
        self.actor_losses = []
        self.critic_losses = []
        self.action_low = None  # Add this line
        self.action_high = None  # Add this line

    def _on_step(self):

        if self.action_low is None:
            self.action_low = self.model.action_space.low[0]  # 0.0
            self.action_high = self.model.action_space.high[0]  # 0.4

        if torch.is_tensor(self.locals['actions']):
            gamma = self.locals['actions'][0].item()
        else:
            gamma = float(self.locals['actions'][0])

        gamma = np.clip(gamma, self.action_low, self.action_high)
        self.current_episode_gammas.append(gamma)

        
        # Track rewards
        if torch.is_tensor(self.locals['rewards']):
            reward = self.locals['rewards'][0].item()
        else:
            reward = float(self.locals['rewards'][0])
        self.total_reward += reward
        
        # Grab actor/critic loss from the SB3 logger if available
        if (hasattr(self.model, 'logger') 
            and hasattr(self.model.logger, 'name_to_value')):
            # Actor (policy) loss
            if 'train/policy_gradient_loss' in self.model.logger.name_to_value:
                self.actor_losses.append(
                    self.model.logger.name_to_value['train/policy_gradient_loss']
                )
            # Critic (value) loss
            if 'train/value_loss' in self.model.logger.name_to_value:
                self.critic_losses.append(
                    self.model.logger.name_to_value['train/value_loss']
                )
        
        # Check if the episode ended
        if self.locals['dones'][0]:
            # Store final metrics of this episode
            self.episode_rewards.append(self.total_reward)
            self.episode_gammas.append(np.mean(self.current_episode_gammas))
            
            # Reset for next episode
            self.current_episode_gammas = []
            self.total_reward = 0
        
        return True

    def save_metrics(self, save_dir="training_metrics"):
        os.makedirs(save_dir, exist_ok=True)
        
        # 1) Plot average reward per episode
        plt.figure(figsize=(8, 5))
        plt.plot(self.episode_rewards, label="Episode Reward")
        plt.title('Average Reward per Episode')
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.grid(True)
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'average_reward.png'))
        plt.close()
        
        # 2) Plot average gamma per episode
        plt.figure(figsize=(8, 5))
        plt.plot(self.episode_gammas, label="Average Gamma")
        plt.title('Average Gamma per Episode')
        plt.xlabel('Episode')
        plt.ylabel('Gamma')
        plt.grid(True)
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'average_gamma.png'))
        plt.close()
        
        # 3) Plot actor & critic loss (if we have them)
        if self.actor_losses and self.critic_losses:
            plt.figure(figsize=(8, 5))
            plt.plot(self.actor_losses, label="Actor Loss")
            plt.plot(self.critic_losses, label="Critic Loss")
            plt.title('Actor & Critic Loss')
            plt.xlabel('Training Update (not per step)')
            plt.ylabel('Loss')
            plt.grid(True)
            plt.legend()
            plt.savefig(os.path.join(save_dir, 'actor_critic_loss.png'))
            plt.close()

        # (Optional) Save summary stats
        with open(os.path.join(save_dir, 'training_summary.txt'), 'w') as f:
            f.write(f"Total Episodes: {len(self.episode_rewards)}\n")
            if len(self.episode_rewards) > 0:
                f.write(f"Overall Average Reward: {np.mean(self.episode_rewards):.3f}\n")
                f.write(f"Overall Average Gamma: {np.mean(self.episode_gammas):.3f}\n")
                f.write(f"Best Episode Reward: {max(self.episode_rewards):.3f}\n")
                f.write(f"Worst Episode Reward: {min(self.episode_rewards):.3f}\n")

class DynamicArbitrationEnv(gym.Env):
    def __init__(self, render_mode=None):
        super().__init__()
        self.render_mode = render_mode
        self.max_dist = np.sqrt(FULL_VIEW_SIZE[0]**2 + FULL_VIEW_SIZE[1]**2)
        
        # Target change parameters
        self.change_target_interval = 50  # Change target every N steps
        self.steps_since_target_change = 0
        self.target_pos = None
        
        # Distance thresholds for gamma targeting
        self.VERY_CLOSE_THRESHOLD = 0.1  # Normalized distance for 0.4 gamma
        self.CLOSE_THRESHOLD = 0.2       # Start increasing gamma
        
        # Same observation and action spaces
        self.observation_space = spaces.Box(
            low=np.array([0, 0, -1, -1, 0, 0, -1, -1, 0]),
            high=np.array([
                FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1],
                1, 1,
                FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1],
                1, 1,
                1
            ]),
            dtype=np.float32
        )
        
        self.action_space = spaces.Box(
            low=np.array([0.0]),
            high=np.array([0.4]),
            dtype=np.float32
        )
        
        self.dot_pos = None
        self.step_count = 0
        self.max_steps = 300

    # Keep _generate_target, _get_obs, and reset methods the same
    def _generate_target(self):
        """Generate a new target position, away from current position"""
        while True:
            x = np.random.uniform(100, FULL_VIEW_SIZE[0] - 100)
            y = np.random.uniform(100, FULL_VIEW_SIZE[1] - 100)
            new_pos = np.array([x, y], dtype=np.float32)
            
            if self.target_pos is not None:
                dist_to_old = np.linalg.norm(new_pos - self.target_pos)
                if dist_to_old < FULL_VIEW_SIZE[0] / 4:
                    continue
            
            if self.dot_pos is not None:
                dist_to_dot = np.linalg.norm(new_pos - self.dot_pos)
                if dist_to_dot < GOAL_DETECTION_RADIUS * 2:
                    continue
            
            return new_pos

    def _get_obs(self):
        to_target = self.target_pos - self.dot_pos
        dist = np.linalg.norm(to_target)
        perfect_dir = to_target / dist if dist > 0 else np.array([0, 0])
        normalized_dist = dist / self.max_dist

        noise = np.random.normal(0, NOISE_MAGNITUDE, size=2)
        human_input = perfect_dir + noise
        if np.linalg.norm(human_input) > 0:
            human_input = human_input / np.linalg.norm(human_input)

        return np.concatenate([
            self.dot_pos,
            human_input,
            self.target_pos,
            perfect_dir,
            [normalized_dist]
        ])

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.dot_pos = np.array(START_POS, dtype=np.float32)
        self.target_pos = self._generate_target()
        self.step_count = 0
        self.steps_since_target_change = 0
        return self._get_obs(), {}

    def step(self, action):
        self.step_count += 1
        self.steps_since_target_change += 1
        
        # Get gamma from action
        gamma = float(np.clip(action[0], 0.0, 0.4))
        
        # Get current observation
        obs = self._get_obs()
        human_input = obs[2:4]
        perfect_dir = obs[6:8]
        normalized_dist = obs[8]  # This is distance/max_dist
        
        # Movement logic (same as before)
        combined_dir = gamma * perfect_dir + (1 - gamma) * human_input
        if np.linalg.norm(combined_dir) > 0:
            combined_dir = combined_dir / np.linalg.norm(combined_dir)
        
        move_speed = combined_dir * MAX_SPEED
        new_pos = self.dot_pos + move_speed
        self.dot_pos = np.clip(new_pos, [0, 0], [FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1]])
        
        # Distance calculations
        dist_to_target = np.linalg.norm(self.target_pos - self.dot_pos)
        goal_radius_norm = GOAL_DETECTION_RADIUS / self.max_dist
        
        # Define distance thresholds relative to goal radius
        # In the step function:

# Define distance thresholds relative to goal radius
        VERY_CLOSE_THRESHOLD = goal_radius_norm * 2.0  
        CLOSE_THRESHOLD = goal_radius_norm * 4.0      
        MID_THRESHOLD = goal_radius_norm * 8.0        

        # Gamma targeting with smoother transitions
        if normalized_dist < VERY_CLOSE_THRESHOLD:  # Very close - smoothly approach 0.4
            progress_ratio = 1.0 - (normalized_dist / VERY_CLOSE_THRESHOLD)  # 0 to 1
            target_gamma = 0.2 + (0.2 * progress_ratio)  # Smoothly go from 0.2 to 0.4
            # Stronger but still smooth penalty
            gamma_reward = -25.0 * ((gamma - target_gamma) ** 2)
            
        elif normalized_dist < CLOSE_THRESHOLD:  # Transition zone
            progress_ratio = 1.0 - ((normalized_dist - VERY_CLOSE_THRESHOLD) / (CLOSE_THRESHOLD - VERY_CLOSE_THRESHOLD))
            target_gamma = 0.2 + (0.1 * progress_ratio)  # Smoothly go from 0.2 to 0.3
            gamma_reward = -15.0 * ((gamma - target_gamma) ** 2)
            
        else:  # Far from target
            target_gamma = 0.2
            # Less aggressive penalty when gamma is too low
            if gamma < target_gamma:
                gamma_reward = -5.0 * (gamma - target_gamma) ** 2
            # More aggressive penalty when gamma is too high
            else:
                gamma_reward = -20.0 * (gamma - target_gamma) ** 2
        # Small alignment reward
        human_alignment = np.dot(combined_dir, human_input)
        alignment_reward = 0.1 * human_alignment
        
        # Goal and target change logic
        terminated = False
        truncated = False
        goal_reward = 0.0
        
        # Check if reached current target
        if dist_to_target < GOAL_DETECTION_RADIUS:
            if normalized_dist < VERY_CLOSE_THRESHOLD:
                if gamma > 0.35:
                    goal_reward = 50.0  # Big bonus for high gamma at goal
                elif gamma > 0.3:
                    goal_reward = 20.0  # Medium bonus for moderately high gamma
                else:
                    goal_reward = 5.0   # Small reward otherwise
            else:
                goal_reward = 5.0
            
            self.target_pos = self._generate_target()
            self.steps_since_target_change = 0
            
        elif self.steps_since_target_change >= self.change_target_interval:
            self.target_pos = self._generate_target()
            self.steps_since_target_change = 0
            if gamma <= 0.25:
                goal_reward = 0.5
                
        if self.step_count >= self.max_steps:
            truncated = True
        
        # Combined reward
        reward = ( 
                 5.0 * gamma_reward +     # Reduced weight for smoother transitions
                 0.1 * alignment_reward + # Minimal alignment importance
                 goal_reward
                 )
        
        
        if self.render_mode == "human":
            self.render(human_input, perfect_dir, combined_dir, gamma, reward)
        
        return self._get_obs(), reward, terminated, truncated, {}

    def render(self, human_input, perfect_dir, combined_dir, gamma, reward):
        # Basic pygame rendering at ~60 FPS
        current_time = time.time()
        if current_time - self.last_render_time < 1/60:
            return
        self.last_render_time = current_time
        
        self.screen.fill(WHITE)
        
        pygame.draw.circle(self.screen, YELLOW, 
                           (int(self.target_pos[0]), int(self.target_pos[1])), 
                           TARGET_RADIUS)
        
        pygame.draw.circle(self.screen, BLACK, 
                           (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                           DOT_RADIUS, 2)
        
        arrow_length = 50
        
        # Perfect direction (green)
        end_pos = (int(self.dot_pos[0] + perfect_dir[0] * arrow_length),
                   int(self.dot_pos[1] + perfect_dir[1] * arrow_length))
        pygame.draw.line(self.screen, GREEN, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
                        
        # Human direction (blue)
        end_pos = (int(self.dot_pos[0] + human_input[0] * arrow_length),
                   int(self.dot_pos[1] + human_input[1] * arrow_length))
        pygame.draw.line(self.screen, BLUE, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
                        
        # Combined direction (red)
        end_pos = (int(self.dot_pos[0] + combined_dir[0] * arrow_length),
                   int(self.dot_pos[1] + combined_dir[1] * arrow_length))
        pygame.draw.line(self.screen, RED, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
        
        texts = [
            f"Step: {self.step_count}",
            f"Gamma: {gamma:.2f}",
            f"Reward: {reward:.2f}",
            f"Steps until target change: {self.change_target_interval - self.steps_since_target_change}"
        ]
        
        for i, text in enumerate(texts):
            text_surface = self.font.render(text, True, BLACK)
            self.screen.blit(text_surface, (10, 10 + i*25))
        
        pygame.display.flip()

def make_env(rank, seed=0):
    def _init():
        env = DynamicArbitrationEnv(render_mode=None)
        env.reset(seed=seed + rank)
        return env
    set_random_seed(seed)
    return _init

def train():
    # Create directories if they don't exist
    model_save_dir = "trained_models"
    metrics_dir = "training_metrics"
    os.makedirs(model_save_dir, exist_ok=True)
    os.makedirs(metrics_dir, exist_ok=True)
    
    n_envs = 64
    env = DummyVecEnv([make_env(i) for i in range(n_envs)])
    
    policy_kwargs = dict(
        features_extractor_class=OptimizedCustomFeaturesExtractor,
        features_extractor_kwargs=dict(features_dim=128),
        net_arch=dict(
            pi=[256, 128],
            vf=[256, 128]
        )
    )
    
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=3e-5,      
        n_steps=256,            
        batch_size=2048,
        ent_coef=0.005,         
        n_epochs=4,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        normalize_advantage=True,
        policy_kwargs=policy_kwargs,
        device=device,
        verbose=1
    )
    
    # Create metrics callback
    metrics_callback = MetricsCallback()
    
    try:
        print("Starting training...")
        model.learn(
            total_timesteps=25_000_000,
            callback=metrics_callback
        )
        
        # Save the model
        model.save("dynamic_arbitration_ppo")
        print("Model saved as dynamic_arbitration_ppo.zip")
        
        # Save the metrics
        metrics_callback.save_metrics()
        print("Metrics saved to training_metrics directory")
        
    except KeyboardInterrupt:
        print("\nTraining interrupted. Saving current state...")
        model.save("dynamic_arbitration_ppo_interrupted")
        metrics_callback.save_metrics(save_dir="training_metrics_interrupted")
        print("Intermediate state saved")
    
    finally:
        env.close()

if __name__ == "__main__":
    mp.set_start_method('spawn', force=True)
    train()
# Out:
# Using device: cuda
# Using cuda device
# Starting training...
# C:\Users\tnlab\AppData\Local\Temp\ipykernel_9336\2265921747.py:97: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   gamma = float(self.locals['actions'][0])
# ------------------------------
# | time/              |       |
# |    fps             | 11083 |
# |    iterations      | 1     |
# |    time_elapsed    | 1     |
# |    total_timesteps | 16384 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10439        |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 9.157782e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00206      |
# |    learning_rate        | 3e-05        |
# |    loss                 | 617          |
# |    n_updates            | 4            |
# |    policy_gradient_loss | 8.04e-05     |
# |    std                  | 0.999        |
# |    value_loss           | 1.26e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10508         |
# |    iterations           | 3             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 3.1127496e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0215        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 553           |
# |    n_updates            | 8             |
# |    policy_gradient_loss | -0.000224     |
# |    std                  | 0.999         |
# |    value_loss           | 1.11e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10646         |
# |    iterations           | 4             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 5.0957362e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0441        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 536           |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.000254     |
# |    std                  | 0.998         |
# |    value_loss           | 1.09e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10744        |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 2.047051e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0628       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 520          |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -1.09e-05    |
# |    std                  | 0.998        |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10719         |
# |    iterations           | 6             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.8024632e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.072         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 543           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000215     |
# |    std                  | 0.997         |
# |    value_loss           | 1.08e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10646         |
# |    iterations           | 7             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 114688        |
# | train/                  |               |
# |    approx_kl            | 4.2277232e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.074         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 559           |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.000375     |
# |    std                  | 0.996         |
# |    value_loss           | 1.13e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10668        |
# |    iterations           | 8            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 5.437721e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 555          |
# |    n_updates            | 28           |
# |    policy_gradient_loss | 7.14e-05     |
# |    std                  | 0.995        |
# |    value_loss           | 1.16e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10657         |
# |    iterations           | 9             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 147456        |
# | train/                  |               |
# |    approx_kl            | 4.3842774e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.149         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 577           |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.000556     |
# |    std                  | 0.995         |
# |    value_loss           | 1.15e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10616        |
# |    iterations           | 10           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 3.679947e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 550          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.000312    |
# |    std                  | 0.994        |
# |    value_loss           | 1.11e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10575         |
# |    iterations           | 11            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 3.8877835e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.157         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 575           |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000577     |
# |    std                  | 0.994         |
# |    value_loss           | 1.13e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10555        |
# |    iterations           | 12           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 7.263681e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 513          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | 0.000152     |
# |    std                  | 0.993        |
# |    value_loss           | 1.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10537        |
# |    iterations           | 13           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 5.622918e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 515          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | 0.000219     |
# |    std                  | 0.993        |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10537         |
# |    iterations           | 14            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 229376        |
# | train/                  |               |
# |    approx_kl            | 4.1592335e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.141         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 546           |
# |    n_updates            | 52            |
# |    policy_gradient_loss | -0.000634     |
# |    std                  | 0.992         |
# |    value_loss           | 1.12e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10587        |
# |    iterations           | 15           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 6.521614e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 556          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | 0.000398     |
# |    std                  | 0.992        |
# |    value_loss           | 1.13e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10629        |
# |    iterations           | 16           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 4.566766e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 559          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000367    |
# |    std                  | 0.991        |
# |    value_loss           | 1.11e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10600         |
# |    iterations           | 17            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 278528        |
# | train/                  |               |
# |    approx_kl            | 6.5673186e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.173         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 529           |
# |    n_updates            | 64            |
# |    policy_gradient_loss | -0.000672     |
# |    std                  | 0.991         |
# |    value_loss           | 1.07e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10606         |
# |    iterations           | 18            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 294912        |
# | train/                  |               |
# |    approx_kl            | 4.3779906e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.125         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 504           |
# |    n_updates            | 68            |
# |    policy_gradient_loss | -6.01e-05     |
# |    std                  | 0.99          |
# |    value_loss           | 1.04e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10607         |
# |    iterations           | 19            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 311296        |
# | train/                  |               |
# |    approx_kl            | 6.0258597e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 508           |
# |    n_updates            | 72            |
# |    policy_gradient_loss | -0.000484     |
# |    std                  | 0.99          |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10591        |
# |    iterations           | 20           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 4.803962e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 483          |
# |    n_updates            | 76           |
# |    policy_gradient_loss | 0.000549     |
# |    std                  | 0.99         |
# |    value_loss           | 970          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10572        |
# |    iterations           | 21           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 4.853554e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0761       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 551          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000175    |
# |    std                  | 0.989        |
# |    value_loss           | 1.1e+03      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10615         |
# |    iterations           | 22            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 360448        |
# | train/                  |               |
# |    approx_kl            | 0.00012028833 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.198         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 580           |
# |    n_updates            | 84            |
# |    policy_gradient_loss | -0.000379     |
# |    std                  | 0.989         |
# |    value_loss           | 1.16e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10621         |
# |    iterations           | 23            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 376832        |
# | train/                  |               |
# |    approx_kl            | 0.00012605528 |
# |    clip_fraction        | 0.000107      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.151         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 536           |
# |    n_updates            | 88            |
# |    policy_gradient_loss | 7.77e-05      |
# |    std                  | 0.989         |
# |    value_loss           | 1.07e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10601         |
# |    iterations           | 24            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 393216        |
# | train/                  |               |
# |    approx_kl            | 0.00016475697 |
# |    clip_fraction        | 0.000336      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.125         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 542           |
# |    n_updates            | 92            |
# |    policy_gradient_loss | -0.000392     |
# |    std                  | 0.988         |
# |    value_loss           | 1.1e+03       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10571         |
# |    iterations           | 25            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 409600        |
# | train/                  |               |
# |    approx_kl            | 0.00022110307 |
# |    clip_fraction        | 4.58e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.186         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 524           |
# |    n_updates            | 96            |
# |    policy_gradient_loss | -0.000844     |
# |    std                  | 0.988         |
# |    value_loss           | 1.06e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10601         |
# |    iterations           | 26            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 425984        |
# | train/                  |               |
# |    approx_kl            | 0.00026352832 |
# |    clip_fraction        | 6.1e-05       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.151         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 483           |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.000622      |
# |    std                  | 0.988         |
# |    value_loss           | 1.02e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10629        |
# |    iterations           | 27           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 8.273049e-05 |
# |    clip_fraction        | 0.000214     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0948       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 501          |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.000447    |
# |    std                  | 0.987        |
# |    value_loss           | 1.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10616        |
# |    iterations           | 28           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 7.847164e-05 |
# |    clip_fraction        | 7.63e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 513          |
# |    n_updates            | 108          |
# |    policy_gradient_loss | 0.000425     |
# |    std                  | 0.987        |
# |    value_loss           | 1.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10604        |
# |    iterations           | 29           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 6.414796e-05 |
# |    clip_fraction        | 3.05e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 564          |
# |    n_updates            | 112          |
# |    policy_gradient_loss | 0.000646     |
# |    std                  | 0.987        |
# |    value_loss           | 1.13e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10583         |
# |    iterations           | 30            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 491520        |
# | train/                  |               |
# |    approx_kl            | 0.00029719068 |
# |    clip_fraction        | 7.63e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.177         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 487           |
# |    n_updates            | 116           |
# |    policy_gradient_loss | -0.00131      |
# |    std                  | 0.986         |
# |    value_loss           | 976           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10562         |
# |    iterations           | 31            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 507904        |
# | train/                  |               |
# |    approx_kl            | 3.3728633e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.122         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 495           |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 0.000162      |
# |    std                  | 0.986         |
# |    value_loss           | 990           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10557         |
# |    iterations           | 32            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 524288        |
# | train/                  |               |
# |    approx_kl            | 3.9614868e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.111         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 519           |
# |    n_updates            | 124           |
# |    policy_gradient_loss | -0.000246     |
# |    std                  | 0.986         |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10542        |
# |    iterations           | 33           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 6.986938e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 487          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -5.18e-05    |
# |    std                  | 0.985        |
# |    value_loss           | 991          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10517         |
# |    iterations           | 34            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 557056        |
# | train/                  |               |
# |    approx_kl            | 6.2325365e-05 |
# |    clip_fraction        | 6.1e-05       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.101         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 501           |
# |    n_updates            | 132           |
# |    policy_gradient_loss | -0.000425     |
# |    std                  | 0.985         |
# |    value_loss           | 1.01e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10477         |
# |    iterations           | 35            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 573440        |
# | train/                  |               |
# |    approx_kl            | 4.0946765e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.13          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 544           |
# |    n_updates            | 136           |
# |    policy_gradient_loss | 0.000222      |
# |    std                  | 0.985         |
# |    value_loss           | 1.08e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10451        |
# |    iterations           | 36           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 8.102263e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 534          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000801    |
# |    std                  | 0.984        |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10448         |
# |    iterations           | 37            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 606208        |
# | train/                  |               |
# |    approx_kl            | 4.0975603e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.113         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 491           |
# |    n_updates            | 144           |
# |    policy_gradient_loss | 6.78e-05      |
# |    std                  | 0.984         |
# |    value_loss           | 978           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10426        |
# |    iterations           | 38           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 9.164892e-05 |
# |    clip_fraction        | 6.1e-05      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 462          |
# |    n_updates            | 148          |
# |    policy_gradient_loss | 0.000648     |
# |    std                  | 0.983        |
# |    value_loss           | 932          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10407        |
# |    iterations           | 39           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 6.605362e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0288       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 463          |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 0.000248     |
# |    std                  | 0.983        |
# |    value_loss           | 925          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10405         |
# |    iterations           | 40            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 655360        |
# | train/                  |               |
# |    approx_kl            | 0.00015779186 |
# |    clip_fraction        | 0.000122      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.108         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 515           |
# |    n_updates            | 156           |
# |    policy_gradient_loss | -0.000922     |
# |    std                  | 0.983         |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10431        |
# |    iterations           | 41           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 4.669008e-05 |
# |    clip_fraction        | 1.53e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 490          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000257    |
# |    std                  | 0.982        |
# |    value_loss           | 985          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10455        |
# |    iterations           | 42           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0004770764 |
# |    clip_fraction        | 0.000595     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 506          |
# |    n_updates            | 164          |
# |    policy_gradient_loss | 0.00219      |
# |    std                  | 0.982        |
# |    value_loss           | 1.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10446        |
# |    iterations           | 43           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0002668424 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0422       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 535          |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000897    |
# |    std                  | 0.981        |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10440         |
# |    iterations           | 44            |
# |    time_elapsed         | 69            |
# |    total_timesteps      | 720896        |
# | train/                  |               |
# |    approx_kl            | 0.00015992294 |
# |    clip_fraction        | 3.05e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.0318        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 474           |
# |    n_updates            | 172           |
# |    policy_gradient_loss | -0.00102      |
# |    std                  | 0.981         |
# |    value_loss           | 952           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10437         |
# |    iterations           | 45            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 737280        |
# | train/                  |               |
# |    approx_kl            | 0.00010693498 |
# |    clip_fraction        | 4.58e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.0671        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 469           |
# |    n_updates            | 176           |
# |    policy_gradient_loss | 0.000119      |
# |    std                  | 0.98          |
# |    value_loss           | 935           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10438         |
# |    iterations           | 46            |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 753664        |
# | train/                  |               |
# |    approx_kl            | 0.00017148707 |
# |    clip_fraction        | 4.58e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.0277        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 457           |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 0.000528      |
# |    std                  | 0.98          |
# |    value_loss           | 918           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10422         |
# |    iterations           | 47            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 770048        |
# | train/                  |               |
# |    approx_kl            | 5.6580124e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.107         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 461           |
# |    n_updates            | 184           |
# |    policy_gradient_loss | -0.00035      |
# |    std                  | 0.98          |
# |    value_loss           | 931           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10434        |
# |    iterations           | 48           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 9.396799e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0794       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 469          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.000494    |
# |    std                  | 0.979        |
# |    value_loss           | 955          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10439       |
# |    iterations           | 49          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 7.04018e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.0705      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 522         |
# |    n_updates            | 192         |
# |    policy_gradient_loss | 0.000252    |
# |    std                  | 0.979       |
# |    value_loss           | 1.07e+03    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10437         |
# |    iterations           | 50            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 819200        |
# | train/                  |               |
# |    approx_kl            | 0.00011355256 |
# |    clip_fraction        | 0.000107      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.0637        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 480           |
# |    n_updates            | 196           |
# |    policy_gradient_loss | -0.000255     |
# |    std                  | 0.978         |
# |    value_loss           | 974           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10440        |
# |    iterations           | 51           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0001670885 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0364       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 480          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 6.82e-05     |
# |    std                  | 0.978        |
# |    value_loss           | 967          |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 10434          |
# |    iterations           | 52             |
# |    time_elapsed         | 81             |
# |    total_timesteps      | 851968         |
# | train/                  |                |
# |    approx_kl            | 0.000100255755 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.4           |
# |    explained_variance   | 0.0331         |
# |    learning_rate        | 3e-05          |
# |    loss                 | 454            |
# |    n_updates            | 204            |
# |    policy_gradient_loss | -3.42e-05      |
# |    std                  | 0.978          |
# |    value_loss           | 914            |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10441        |
# |    iterations           | 53           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0002672503 |
# |    clip_fraction        | 4.58e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0405       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 474          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | 0.000102     |
# |    std                  | 0.978        |
# |    value_loss           | 949          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10443         |
# |    iterations           | 54            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 884736        |
# | train/                  |               |
# |    approx_kl            | 0.00015090124 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.0618        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 466           |
# |    n_updates            | 212           |
# |    policy_gradient_loss | -0.000147     |
# |    std                  | 0.977         |
# |    value_loss           | 927           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10447         |
# |    iterations           | 55            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 901120        |
# | train/                  |               |
# |    approx_kl            | 0.00020975439 |
# |    clip_fraction        | 0.000183      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.0644        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 459           |
# |    n_updates            | 216           |
# |    policy_gradient_loss | -0.000209     |
# |    std                  | 0.976         |
# |    value_loss           | 926           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10451         |
# |    iterations           | 56            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 917504        |
# | train/                  |               |
# |    approx_kl            | 0.00023534958 |
# |    clip_fraction        | 0.000137      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.0617        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 530           |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00081      |
# |    std                  | 0.976         |
# |    value_loss           | 1.05e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10446         |
# |    iterations           | 57            |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 933888        |
# | train/                  |               |
# |    approx_kl            | 0.00015537346 |
# |    clip_fraction        | 0.000198      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.0461        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 470           |
# |    n_updates            | 224           |
# |    policy_gradient_loss | 5.87e-05      |
# |    std                  | 0.975         |
# |    value_loss           | 934           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10444         |
# |    iterations           | 58            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 950272        |
# | train/                  |               |
# |    approx_kl            | 0.00013687999 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.06          |
# |    learning_rate        | 3e-05         |
# |    loss                 | 435           |
# |    n_updates            | 228           |
# |    policy_gradient_loss | 0.000979      |
# |    std                  | 0.975         |
# |    value_loss           | 879           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10442         |
# |    iterations           | 59            |
# ...
# |    fps                  | 10125       |
# |    iterations           | 1507        |
# |    time_elapsed         | 2438        |
# |    total_timesteps      | 24690688    |
# | train/                  |             |
# |    approx_kl            | 0.010743738 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 9.94        |
# |    n_updates            | 6024        |
# |    policy_gradient_loss | 0.00761     |
# |    std                  | 0.614       |
# |    value_loss           | 20.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10125       |
# |    iterations           | 1508        |
# |    time_elapsed         | 2440        |
# |    total_timesteps      | 24707072    |
# | train/                  |             |
# |    approx_kl            | 0.014626145 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 10          |
# |    n_updates            | 6028        |
# |    policy_gradient_loss | 0.0178      |
# |    std                  | 0.614       |
# |    value_loss           | 21.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10125      |
# |    iterations           | 1509       |
# |    time_elapsed         | 2441       |
# |    total_timesteps      | 24723456   |
# | train/                  |            |
# |    approx_kl            | 0.01260134 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.93      |
# |    explained_variance   | 0.772      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 8.9        |
# |    n_updates            | 6032       |
# |    policy_gradient_loss | 0.00946    |
# |    std                  | 0.613      |
# |    value_loss           | 19.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10125       |
# |    iterations           | 1510        |
# |    time_elapsed         | 2443        |
# |    total_timesteps      | 24739840    |
# | train/                  |             |
# |    approx_kl            | 0.018574148 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 10.3        |
# |    n_updates            | 6036        |
# |    policy_gradient_loss | 0.0126      |
# |    std                  | 0.613       |
# |    value_loss           | 23.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1511        |
# |    time_elapsed         | 2444        |
# |    total_timesteps      | 24756224    |
# | train/                  |             |
# |    approx_kl            | 0.008297617 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 9.8         |
# |    n_updates            | 6040        |
# |    policy_gradient_loss | 0.00634     |
# |    std                  | 0.613       |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1512        |
# |    time_elapsed         | 2446        |
# |    total_timesteps      | 24772608    |
# | train/                  |             |
# |    approx_kl            | 0.010280311 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 7.42        |
# |    n_updates            | 6044        |
# |    policy_gradient_loss | 0.0059      |
# |    std                  | 0.613       |
# |    value_loss           | 15.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1513        |
# |    time_elapsed         | 2447        |
# |    total_timesteps      | 24788992    |
# | train/                  |             |
# |    approx_kl            | 0.008647161 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 11          |
# |    n_updates            | 6048        |
# |    policy_gradient_loss | 0.00918     |
# |    std                  | 0.612       |
# |    value_loss           | 21.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10127       |
# |    iterations           | 1514        |
# |    time_elapsed         | 2449        |
# |    total_timesteps      | 24805376    |
# | train/                  |             |
# |    approx_kl            | 0.012306805 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 11.8        |
# |    n_updates            | 6052        |
# |    policy_gradient_loss | 0.0093      |
# |    std                  | 0.612       |
# |    value_loss           | 25.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1515        |
# |    time_elapsed         | 2451        |
# |    total_timesteps      | 24821760    |
# | train/                  |             |
# |    approx_kl            | 0.011250763 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 9.16        |
# |    n_updates            | 6056        |
# |    policy_gradient_loss | 0.00505     |
# |    std                  | 0.612       |
# |    value_loss           | 21.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10126        |
# |    iterations           | 1516         |
# |    time_elapsed         | 2452         |
# |    total_timesteps      | 24838144     |
# | train/                  |              |
# |    approx_kl            | 0.0096822195 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 8.5          |
# |    n_updates            | 6060         |
# |    policy_gradient_loss | 0.00727      |
# |    std                  | 0.611        |
# |    value_loss           | 21.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10126        |
# |    iterations           | 1517         |
# |    time_elapsed         | 2454         |
# |    total_timesteps      | 24854528     |
# | train/                  |              |
# |    approx_kl            | 0.0074740276 |
# |    clip_fraction        | 0.0986       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.926       |
# |    explained_variance   | 0.775        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 10.5         |
# |    n_updates            | 6064         |
# |    policy_gradient_loss | 0.0062       |
# |    std                  | 0.611        |
# |    value_loss           | 19.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1518        |
# |    time_elapsed         | 2456        |
# |    total_timesteps      | 24870912    |
# | train/                  |             |
# |    approx_kl            | 0.010913098 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 10.3        |
# |    n_updates            | 6068        |
# |    policy_gradient_loss | 0.0133      |
# |    std                  | 0.611       |
# |    value_loss           | 23          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1519        |
# |    time_elapsed         | 2457        |
# |    total_timesteps      | 24887296    |
# | train/                  |             |
# |    approx_kl            | 0.011799052 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 13.8        |
# |    n_updates            | 6072        |
# |    policy_gradient_loss | 0.0111      |
# |    std                  | 0.61        |
# |    value_loss           | 29.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1520        |
# |    time_elapsed         | 2459        |
# |    total_timesteps      | 24903680    |
# | train/                  |             |
# |    approx_kl            | 0.022565957 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 13.6        |
# |    n_updates            | 6076        |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.61        |
# |    value_loss           | 27.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1521        |
# |    time_elapsed         | 2460        |
# |    total_timesteps      | 24920064    |
# | train/                  |             |
# |    approx_kl            | 0.024850287 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 9.74        |
# |    n_updates            | 6080        |
# |    policy_gradient_loss | 0.026       |
# |    std                  | 0.61        |
# |    value_loss           | 20.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1522        |
# |    time_elapsed         | 2462        |
# |    total_timesteps      | 24936448    |
# | train/                  |             |
# |    approx_kl            | 0.015271073 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 8.57        |
# |    n_updates            | 6084        |
# |    policy_gradient_loss | 0.00959     |
# |    std                  | 0.61        |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1523        |
# |    time_elapsed         | 2464        |
# |    total_timesteps      | 24952832    |
# | train/                  |             |
# |    approx_kl            | 0.015209926 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 10          |
# |    n_updates            | 6088        |
# |    policy_gradient_loss | 0.00804     |
# |    std                  | 0.61        |
# |    value_loss           | 21.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1524        |
# |    time_elapsed         | 2465        |
# |    total_timesteps      | 24969216    |
# | train/                  |             |
# |    approx_kl            | 0.009226345 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 7.71        |
# |    n_updates            | 6092        |
# |    policy_gradient_loss | 0.00391     |
# |    std                  | 0.609       |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10126       |
# |    iterations           | 1525        |
# |    time_elapsed         | 2467        |
# |    total_timesteps      | 24985600    |
# | train/                  |             |
# |    approx_kl            | 0.009617837 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 8.88        |
# |    n_updates            | 6096        |
# |    policy_gradient_loss | 0.0109      |
# |    std                  | 0.609       |
# |    value_loss           | 18.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10125       |
# |    iterations           | 1526        |
# |    time_elapsed         | 2469        |
# |    total_timesteps      | 25001984    |
# | train/                  |             |
# |    approx_kl            | 0.012497075 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 10.6        |
# |    n_updates            | 6100        |
# |    policy_gradient_loss | 0.00829     |
# |    std                  | 0.609       |
# |    value_loss           | 23.5        |
# -----------------------------------------
# Model saved as dynamic_arbitration_ppo.zip
# Metrics saved to training_metrics directory
