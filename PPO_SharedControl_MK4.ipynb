# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.utils import set_random_seed
import torch.multiprocessing as mp

import pygame
import matplotlib.pyplot as plt
import time

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Constants
FULL_VIEW_SIZE = (1200, 800)
MAX_SPEED = 3
DOT_RADIUS = 30
TARGET_RADIUS = 10
GOAL_DETECTION_RADIUS = DOT_RADIUS + TARGET_RADIUS
START_POS = [FULL_VIEW_SIZE[0] // 2, FULL_VIEW_SIZE[1] // 2]
NOISE_MAGNITUDE = 0.5

# Colors
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)
GREEN = (0, 200, 0)
BLUE = (0, 0, 255)
YELLOW = (255, 255, 0)

class OptimizedCustomFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 128):
        super().__init__(observation_space, features_dim)
        
        n_input = int(np.prod(observation_space.shape))
        
        self.network = nn.Sequential(
            nn.Linear(n_input, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Linear(256, features_dim),
            nn.ReLU(),
            nn.BatchNorm1d(features_dim)
        )
        
        # Initialize weights properly
        for m in self.network.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0)
                
    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.network(observations)

class MetricsCallback(BaseCallback):
    """
    Modified callback that tracks:
      - Episode total rewards
      - Average gamma per episode
      - Actor loss and critic loss from SB3 logger
    Then plots:
      1. Average reward per episode
      2. Average gamma per episode
      3. Actor & Critic loss
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_gammas = []
        self.current_episode_gammas = []
        self.total_reward = 0
        
        self.actor_losses = []
        self.critic_losses = []
        self.action_low = None  # Add this line
        self.action_high = None  # Add this line

    def _on_step(self):

        if self.action_low is None:
            self.action_low = self.model.action_space.low[0]  # 0.0
            self.action_high = self.model.action_space.high[0]  # 0.4

        if torch.is_tensor(self.locals['actions']):
            gamma = self.locals['actions'][0].item()
        else:
            gamma = float(self.locals['actions'][0])

        gamma = np.clip(gamma, self.action_low, self.action_high)
        self.current_episode_gammas.append(gamma)

        
        # Track rewards
        if torch.is_tensor(self.locals['rewards']):
            reward = self.locals['rewards'][0].item()
        else:
            reward = float(self.locals['rewards'][0])
        self.total_reward += reward
        
        # Grab actor/critic loss from the SB3 logger if available
        if (hasattr(self.model, 'logger') 
            and hasattr(self.model.logger, 'name_to_value')):
            # Actor (policy) loss
            if 'train/policy_gradient_loss' in self.model.logger.name_to_value:
                self.actor_losses.append(
                    self.model.logger.name_to_value['train/policy_gradient_loss']
                )
            # Critic (value) loss
            if 'train/value_loss' in self.model.logger.name_to_value:
                self.critic_losses.append(
                    self.model.logger.name_to_value['train/value_loss']
                )
        
        # Check if the episode ended
        if self.locals['dones'][0]:
            # Store final metrics of this episode
            self.episode_rewards.append(self.total_reward)
            self.episode_gammas.append(np.mean(self.current_episode_gammas))
            
            # Reset for next episode
            self.current_episode_gammas = []
            self.total_reward = 0
        
        return True

    def save_metrics(self, save_dir="training_metrics"):
        os.makedirs(save_dir, exist_ok=True)
        
        # 1) Plot average reward per episode
        plt.figure(figsize=(8, 5))
        plt.plot(self.episode_rewards, label="Episode Reward")
        plt.title('Average Reward per Episode')
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.grid(True)
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'average_reward.png'))
        plt.close()
        
        # 2) Plot average gamma per episode
        plt.figure(figsize=(8, 5))
        plt.plot(self.episode_gammas, label="Average Gamma")
        plt.title('Average Gamma per Episode')
        plt.xlabel('Episode')
        plt.ylabel('Gamma')
        plt.grid(True)
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'average_gamma.png'))
        plt.close()
        
        # 3) Plot actor & critic loss (if we have them)
        if self.actor_losses and self.critic_losses:
            plt.figure(figsize=(8, 5))
            plt.plot(self.actor_losses, label="Actor Loss")
            plt.plot(self.critic_losses, label="Critic Loss")
            plt.title('Actor & Critic Loss')
            plt.xlabel('Training Update (not per step)')
            plt.ylabel('Loss')
            plt.grid(True)
            plt.legend()
            plt.savefig(os.path.join(save_dir, 'actor_critic_loss.png'))
            plt.close()

        # (Optional) Save summary stats
        with open(os.path.join(save_dir, 'training_summary.txt'), 'w') as f:
            f.write(f"Total Episodes: {len(self.episode_rewards)}\n")
            if len(self.episode_rewards) > 0:
                f.write(f"Overall Average Reward: {np.mean(self.episode_rewards):.3f}\n")
                f.write(f"Overall Average Gamma: {np.mean(self.episode_gammas):.3f}\n")
                f.write(f"Best Episode Reward: {max(self.episode_rewards):.3f}\n")
                f.write(f"Worst Episode Reward: {min(self.episode_rewards):.3f}\n")

class DynamicArbitrationEnv(gym.Env):
    """
    Modified so that gamma is always in [0.0, 0.4].
    A custom reward encourages gamma near 0.4 when close to the goal,
    and gamma near 0.1 when far from the goal.
    """
    def __init__(self, render_mode=None):
        super().__init__()
        self.render_mode = render_mode
        self.max_dist = np.sqrt(FULL_VIEW_SIZE[0]**2 + FULL_VIEW_SIZE[1]**2)
        if render_mode == "human":
            pygame.init()
            self.screen = pygame.display.set_mode(FULL_VIEW_SIZE)
            pygame.display.set_caption("Training Visualization")
            self.font = pygame.font.Font(None, 24)
        
        # Observation space: [dot_pos_x, dot_pos_y, human_input_x, human_input_y, 
        #                    target_pos_x, target_pos_y, perfect_dir_x, perfect_dir_y]
        self.observation_space = spaces.Box(
            low=np.array([0, 0, -1, -1, 0, 0, -1, -1, 0]),
            high=np.array([
                FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1],
                1, 1,
                FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1],
                1, 1, 1
            ], dtype=np.float32),
            dtype=np.float32
        )
        
        # Action space: gamma value between 0.0 and 0.4
        self.action_space = spaces.Box(
            low=np.array([0.0]),
            high=np.array([0.4]),
            dtype=np.float32
        )
        
        self.dot_pos = None
        self.target_pos = None
        self.step_count = 0
        self.max_steps = 300
        self.last_render_time = time.time()
        self.steps_since_target_change = 0
        self.change_target_interval = 50  # Change target every N steps
        

    def _generate_target(self):
        x = np.random.uniform(100, FULL_VIEW_SIZE[0] - 100)
        y = np.random.uniform(100, FULL_VIEW_SIZE[1] - 100)
        return np.array([x, y], dtype=np.float32)

    def _get_obs(self):
        to_target = self.target_pos - self.dot_pos
        dist = np.linalg.norm(to_target)
        perfect_dir = to_target / dist if dist > 0 else np.array([0, 0])
        to_target = self.target_pos - self.dot_pos
        dist_to_target = np.linalg.norm(to_target)
        normalized_dist = dist_to_target / self.max_dist
        
        # Simulate "human" input with some noise
        noise = np.random.normal(0, NOISE_MAGNITUDE, size=2)
        human_input = perfect_dir + noise
        if np.linalg.norm(human_input) > 0:
            human_input = human_input / np.linalg.norm(human_input)
        

        

        return np.concatenate([
            self.dot_pos,
            human_input,
            self.target_pos,
            perfect_dir,
            [normalized_dist]
        ])

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.dot_pos = np.array(START_POS, dtype=np.float32)
        self.target_pos = self._generate_target()
        self.step_count = 0
        self.steps_since_target_change = 0
        return self._get_obs(), {}

    def step(self, action):
        self.step_count += 1
        self.steps_since_target_change += 1
        
        # Gamma is clipped to [0.0, 0.4]
        if isinstance(action, (np.ndarray, list)):
            gamma = float(np.clip(action[0], 0.0, 0.4))
        else:
            gamma = float(np.clip(action, 0.0, 0.4))
        
        obs = self._get_obs()
        human_input = obs[2:4]
        perfect_dir = obs[6:8]
        
        # Combine directions
        combined_dir = gamma * perfect_dir + (1 - gamma) * human_input
        if np.linalg.norm(combined_dir) > 0:
            combined_dir = combined_dir / np.linalg.norm(combined_dir)
        
        # Move agent
        move_speed = combined_dir * MAX_SPEED
        new_pos = self.dot_pos + move_speed
        self.dot_pos = np.clip(new_pos, [0, 0], [FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1]])
        
        # Distance-based rewards
        dist_to_target = np.linalg.norm(self.target_pos - self.dot_pos)
        max_dist = np.sqrt(FULL_VIEW_SIZE[0]**2 + FULL_VIEW_SIZE[1]**2)
        
        # 1) Progress reward: negative of normalized distance
        progress_reward = -dist_to_target / max_dist
        
        # 2) Encourage gamma near 0.4 if close to goal, near 0.1 if far:
        #    ideal_gamma goes from 0.4 (dist=0) to 0.1 (dist=max_dist)
        distance_fraction = dist_to_target / max_dist
        ideal_gamma = 0.4 - 0.3 * distance_fraction  # linear interpolation
        # Clip it just to be safe:
        ideal_gamma = np.clip(ideal_gamma, 0.1, 0.4)
        
        # Negative penalty for deviating from ideal gamma
        gamma_penalty = -(gamma - ideal_gamma)**2
        
        # 3) Additional bonus if combined_dir aligns with "human" input
        human_alignment = np.dot(combined_dir, human_input)
        human_follow_reward = 0.5 * human_alignment
        
        # 4) Total reward
        #    Weighted sum of terms (you can tweak the coefficients):
        reward = 0.05*progress_reward + 0.2*gamma_penalty + 0.8 * human_follow_reward
        
        # Occasionally change target
        if self.steps_since_target_change >= self.change_target_interval:
            self.target_pos = self._generate_target()
            self.steps_since_target_change = 0
            reward += 0.5  # small bonus for changing target
        
        # Check termination
        terminated = False
        truncated = False
        
        if dist_to_target < GOAL_DETECTION_RADIUS:
            # Bonus for reaching the goal
            reward += 10.0
            terminated = True
        elif self.step_count >= self.max_steps:
            truncated = True
        
        if self.render_mode == "human":
            self.render(human_input, perfect_dir, combined_dir, gamma, reward)
        
        return self._get_obs(), reward, terminated, truncated, {}

    def render(self, human_input, perfect_dir, combined_dir, gamma, reward):
        # Basic pygame rendering at ~60 FPS
        current_time = time.time()
        if current_time - self.last_render_time < 1/60:
            return
        self.last_render_time = current_time
        
        self.screen.fill(WHITE)
        
        pygame.draw.circle(self.screen, YELLOW, 
                           (int(self.target_pos[0]), int(self.target_pos[1])), 
                           TARGET_RADIUS)
        
        pygame.draw.circle(self.screen, BLACK, 
                           (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                           DOT_RADIUS, 2)
        
        arrow_length = 50
        
        # Perfect direction (green)
        end_pos = (int(self.dot_pos[0] + perfect_dir[0] * arrow_length),
                   int(self.dot_pos[1] + perfect_dir[1] * arrow_length))
        pygame.draw.line(self.screen, GREEN, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
                        
        # Human direction (blue)
        end_pos = (int(self.dot_pos[0] + human_input[0] * arrow_length),
                   int(self.dot_pos[1] + human_input[1] * arrow_length))
        pygame.draw.line(self.screen, BLUE, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
                        
        # Combined direction (red)
        end_pos = (int(self.dot_pos[0] + combined_dir[0] * arrow_length),
                   int(self.dot_pos[1] + combined_dir[1] * arrow_length))
        pygame.draw.line(self.screen, RED, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
        
        texts = [
            f"Step: {self.step_count}",
            f"Gamma: {gamma:.2f}",
            f"Reward: {reward:.2f}",
            f"Steps until target change: {self.change_target_interval - self.steps_since_target_change}"
        ]
        
        for i, text in enumerate(texts):
            text_surface = self.font.render(text, True, BLACK)
            self.screen.blit(text_surface, (10, 10 + i*25))
        
        pygame.display.flip()

def make_env(rank, seed=0):
    def _init():
        env = DynamicArbitrationEnv(render_mode=None)
        env.reset(seed=seed + rank)
        return env
    set_random_seed(seed)
    return _init

def train():
    # You can switch back to SubprocVecEnv if needed, but DummyVecEnv is simpler to debug
    n_envs = 8
    env = DummyVecEnv([make_env(i) for i in range(n_envs)])
    
    policy_kwargs = dict(
        features_extractor_class=OptimizedCustomFeaturesExtractor,
        features_extractor_kwargs=dict(features_dim=128),
        net_arch=dict(pi=[256, 128],
                      vf=[256, 128])
    )
    
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=2.5e-4,
        n_steps=256,
        batch_size=128,
        ent_coef=0.01,
        n_epochs=4,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        normalize_advantage=True,
        policy_kwargs=policy_kwargs,
        device=device,
        verbose=1
    )
    
    # Create metrics callback
    metrics_callback = MetricsCallback()
    
    try:
        print("Starting training...")
        model.learn(
            total_timesteps=1_000_000,
            callback=metrics_callback
        )
        
        print("Training complete! Saving model and metrics...")
        model.save("dynamic_arbitration_ppo_optimized")
        metrics_callback.save_metrics()
        print("Model and metrics saved!")
        
    except KeyboardInterrupt:
        print("\nTraining interrupted. Saving current model and metrics...")
        model.save("dynamic_arbitration_ppo_optimized_interrupted")
        metrics_callback.save_metrics(save_dir="training_metrics_interrupted")
    
    finally:
        env.close()
        pygame.quit()

if __name__ == "__main__":
    mp.set_start_method('spawn', force=True)
    train()
# Out:
# Using device: cuda
# Using cuda device
# Starting training...
# c:\Users\mhfar\anaconda3\lib\site-packages\gymnasium\spaces\box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# c:\Users\mhfar\anaconda3\lib\site-packages\gymnasium\spaces\box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# c:\Users\mhfar\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# C:\Users\mhfar\AppData\Local\Temp\ipykernel_17084\3506863839.py:97: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   gamma = float(self.locals['actions'][0])
# -----------------------------
# | time/              |      |
# |    fps             | 2647 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2095         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0015569312 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0373       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.66         |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00149     |
# |    std                  | 1            |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1995         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0019786712 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.915        |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00176     |
# |    std                  | 1            |
# |    value_loss           | 11.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1983         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0011322538 |
# |    clip_fraction        | 0.00354      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.05         |
# |    n_updates            | 12           |
# |    policy_gradient_loss | 0.000838     |
# |    std                  | 1            |
# |    value_loss           | 7.76         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1969         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0017285553 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.05         |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 1            |
# |    value_loss           | 7.98         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1957         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0029552106 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.45         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00254     |
# |    std                  | 1            |
# |    value_loss           | 7.35         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1947         |
# |    iterations           | 7            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0018817381 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.17         |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 1            |
# |    value_loss           | 7.22         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1933         |
# |    iterations           | 8            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0007430573 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.386        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.16         |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.000379    |
# |    std                  | 1            |
# |    value_loss           | 10.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1917         |
# |    iterations           | 9            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0013926934 |
# |    clip_fraction        | 0.00183      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.08         |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.000647    |
# |    std                  | 1            |
# |    value_loss           | 7.81         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1921        |
# |    iterations           | 10          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.001628641 |
# |    clip_fraction        | 0.00208     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.18        |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00252    |
# |    std                  | 1           |
# |    value_loss           | 6.26        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1915         |
# |    iterations           | 11           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0017677569 |
# |    clip_fraction        | 0.0033       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.94         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -9.01e-05    |
# |    std                  | 1            |
# |    value_loss           | 8.42         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1918        |
# |    iterations           | 12          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.001741405 |
# |    clip_fraction        | 0.00476     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.91        |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.000284   |
# |    std                  | 1           |
# |    value_loss           | 6.4         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1914         |
# |    iterations           | 13           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0016057165 |
# |    clip_fraction        | 0.00647      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.31         |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00161     |
# |    std                  | 1            |
# |    value_loss           | 13.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1914          |
# |    iterations           | 14            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00084796594 |
# |    clip_fraction        | 0.00134       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.597         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.4           |
# |    n_updates            | 52            |
# |    policy_gradient_loss | -0.000377     |
# |    std                  | 1             |
# |    value_loss           | 8.52          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1911         |
# |    iterations           | 15           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0013283023 |
# |    clip_fraction        | 0.00464      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.85         |
# |    n_updates            | 56           |
# |    policy_gradient_loss | 0.000255     |
# |    std                  | 1            |
# |    value_loss           | 12.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1909        |
# |    iterations           | 16          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003263316 |
# |    clip_fraction        | 0.0265      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.83        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 1           |
# |    value_loss           | 8.84        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1905         |
# |    iterations           | 17           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0016790857 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.9         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | 0.000428     |
# |    std                  | 1            |
# |    value_loss           | 42.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1900         |
# |    iterations           | 18           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012374169 |
# |    clip_fraction        | 0.00305      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.132       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.61         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.000668    |
# |    std                  | 1.01         |
# |    value_loss           | 20           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1901         |
# |    iterations           | 19           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0018645923 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.19         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.000484    |
# |    std                  | 1.01         |
# |    value_loss           | 19.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1901         |
# |    iterations           | 20           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0033077928 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.141       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.78         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | 0.00152      |
# |    std                  | 1.01         |
# |    value_loss           | 23.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 21           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0018987849 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0733       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.05         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 8.93e-05     |
# |    std                  | 1.01         |
# |    value_loss           | 13.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 22           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0012806244 |
# |    clip_fraction        | 0.00623      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.09         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000642    |
# |    std                  | 1.01         |
# |    value_loss           | 8.16         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1900         |
# |    iterations           | 23           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0018988996 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.125       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.865        |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 1.01         |
# |    value_loss           | 5.37         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1898         |
# |    iterations           | 24           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0036664812 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.45         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 1.01         |
# |    value_loss           | 5.07         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 25          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.001478303 |
# |    clip_fraction        | 0.00513     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.21        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 1.01        |
# |    value_loss           | 7.5         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1897         |
# |    iterations           | 26           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0026278025 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.24         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.000334     |
# |    std                  | 1.01         |
# |    value_loss           | 13.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1900         |
# |    iterations           | 27           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0031646225 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.67         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.0019      |
# |    std                  | 1            |
# |    value_loss           | 5.98         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 28           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0027025854 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.475        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.94         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00357     |
# |    std                  | 1            |
# |    value_loss           | 4.31         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1898         |
# |    iterations           | 29           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0016141667 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.313        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.25         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | 0.00507      |
# |    std                  | 1            |
# |    value_loss           | 15.2         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1893       |
# |    iterations           | 30         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00570489 |
# |    clip_fraction        | 0.0327     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.57       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.89       |
# |    n_updates            | 116        |
# |    policy_gradient_loss | 0.0017     |
# |    std                  | 1          |
# |    value_loss           | 9.06       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1893       |
# |    iterations           | 31         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00209398 |
# |    clip_fraction        | 0.0094     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.427      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.57       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0012    |
# |    std                  | 0.999      |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 32           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0036341427 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.06         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00161     |
# |    std                  | 0.994        |
# |    value_loss           | 5.55         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 33           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0062020933 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.19         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | 0.00224      |
# |    std                  | 0.992        |
# |    value_loss           | 8.01         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 34           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0027290012 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.693        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.756        |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000915    |
# |    std                  | 0.991        |
# |    value_loss           | 3.27         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1892         |
# |    iterations           | 35           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0021927496 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.567        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.14         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | 0.00224      |
# |    std                  | 0.992        |
# |    value_loss           | 9.95         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1892        |
# |    iterations           | 36          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005071027 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.57        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00104    |
# |    std                  | 0.988       |
# |    value_loss           | 8           |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1892        |
# |    iterations           | 37          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.001103436 |
# |    clip_fraction        | 0.00305     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.95        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | 0.00102     |
# |    std                  | 0.986       |
# |    value_loss           | 9.98        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 38           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0024114358 |
# |    clip_fraction        | 0.0094       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.44         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | 0.000933     |
# |    std                  | 0.985        |
# |    value_loss           | 9.91         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 39           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0021335096 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.341        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.78         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 2.33e-05     |
# |    std                  | 0.987        |
# |    value_loss           | 13.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1892         |
# |    iterations           | 40           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0019729058 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.5          |
# |    n_updates            | 156          |
# |    policy_gradient_loss | 0.00206      |
# |    std                  | 0.986        |
# |    value_loss           | 11.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1893         |
# |    iterations           | 41           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0025504548 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.39         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00168      |
# |    std                  | 0.987        |
# |    value_loss           | 6.8          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1894         |
# |    iterations           | 42           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0012318296 |
# |    clip_fraction        | 0.00354      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.722        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.688        |
# |    n_updates            | 164          |
# |    policy_gradient_loss | 2.51e-06     |
# |    std                  | 0.985        |
# |    value_loss           | 3.65         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1895        |
# |    iterations           | 43          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003240415 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.01        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.00161    |
# |    std                  | 0.988       |
# |    value_loss           | 5.59        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 44           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0044241035 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0858       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.938        |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.00017     |
# |    std                  | 0.988        |
# |    value_loss           | 5.06         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 45           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0026350962 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.57         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.00075     |
# |    std                  | 0.988        |
# |    value_loss           | 10.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 46           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0018771997 |
# |    clip_fraction        | 0.00867      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.37         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000941     |
# |    std                  | 0.986        |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 47           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0020613992 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0581       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.72         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00318     |
# |    std                  | 0.985        |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1892         |
# |    iterations           | 48           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0019946117 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.74         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.000607    |
# |    std                  | 0.986        |
# |    value_loss           | 11.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1894         |
# |    iterations           | 49           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0013878333 |
# |    clip_fraction        | 0.00623      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.67         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.988        |
# |    value_loss           | 7.33         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1894         |
# |    iterations           | 50           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0015644118 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.25         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00173     |
# |    std                  | 0.984        |
# |    value_loss           | 8.74         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1895         |
# |    iterations           | 51           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0022099921 |
# |    clip_fraction        | 0.00793      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.308        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.5         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000562    |
# |    std                  | 0.98         |
# |    value_loss           | 19.1         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1894          |
# |    iterations           | 52            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00080441043 |
# |    clip_fraction        | 0.00269       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.185         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.6           |
# |    n_updates            | 204           |
# |    policy_gradient_loss | 0.00145       |
# |    std                  | 0.979         |
# |    value_loss           | 25.9          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1893         |
# |    iterations           | 53           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0032117555 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.49         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00129     |
# |    std                  | 0.976        |
# |    value_loss           | 9.42         |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1892      |
# |    iterations           | 54        |
# |    time_elapsed         | 58        |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 0.0052085 |
# |    clip_fraction        | 0.0358    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.39     |
# |    explained_variance   | 0.439     |
# |    learning_rate        | 0.00025   |
# |    loss                 | 2.94      |
# |    n_updates            | 212       |
# |    policy_gradient_loss | -0.00178  |
# |    std                  | 0.977     |
# |    value_loss           | 11.1      |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 55           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0028212555 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.909        |
# |    n_updates            | 216          |
# |    policy_gradient_loss | 1.05e-05     |
# |    std                  | 0.969        |
# |    value_loss           | 3.67         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 56          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.001487907 |
# |    clip_fraction        | 0.00757     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.3        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.967       |
# |    value_loss           | 26.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 57          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.002332631 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11          |
# |    n_updates            | 224         |
# |    policy_gradient_loss | 0.00291     |
# |    std                  | 0.968       |
# |    value_loss           | 20.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 58           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0024535712 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.19         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 0.968        |
# |    value_loss           | 11.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1886        |
# ...
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.35        |
# |    n_updates            | 1876        |
# |    policy_gradient_loss | -0.00168    |
# |    std                  | 1.06        |
# |    value_loss           | 5.56        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 471          |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 964608       |
# | train/                  |              |
# |    approx_kl            | 0.0022121284 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.847        |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | 0.00165      |
# |    std                  | 1.06         |
# |    value_loss           | 4.85         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 472          |
# |    time_elapsed         | 520          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0047126166 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.651        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.01         |
# |    n_updates            | 1884         |
# |    policy_gradient_loss | -0.00328     |
# |    std                  | 1.06         |
# |    value_loss           | 4.38         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 473          |
# |    time_elapsed         | 522          |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0057492615 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.518        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.28         |
# |    n_updates            | 1888         |
# |    policy_gradient_loss | -0.00226     |
# |    std                  | 1.06         |
# |    value_loss           | 5.15         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 474          |
# |    time_elapsed         | 523          |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0056103747 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.982        |
# |    n_updates            | 1892         |
# |    policy_gradient_loss | -0.00224     |
# |    std                  | 1.07         |
# |    value_loss           | 3.73         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1855        |
# |    iterations           | 475         |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.002357551 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.5         |
# |    n_updates            | 1896        |
# |    policy_gradient_loss | 0.000475    |
# |    std                  | 1.07        |
# |    value_loss           | 5.92        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1855        |
# |    iterations           | 476         |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.004880398 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.13        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.00167     |
# |    std                  | 1.07        |
# |    value_loss           | 4.49        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 477          |
# |    time_elapsed         | 526          |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0033452467 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.522        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.19         |
# |    n_updates            | 1904         |
# |    policy_gradient_loss | -7.45e-05    |
# |    std                  | 1.07         |
# |    value_loss           | 5.92         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 478          |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0032306656 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.821        |
# |    n_updates            | 1908         |
# |    policy_gradient_loss | -0.00107     |
# |    std                  | 1.07         |
# |    value_loss           | 4            |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1855        |
# |    iterations           | 479         |
# |    time_elapsed         | 528         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.004421223 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.44        |
# |    n_updates            | 1912        |
# |    policy_gradient_loss | -0.0032     |
# |    std                  | 1.07        |
# |    value_loss           | 6.13        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1855        |
# |    iterations           | 480         |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.005990967 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.62        |
# |    n_updates            | 1916        |
# |    policy_gradient_loss | -0.000233   |
# |    std                  | 1.07        |
# |    value_loss           | 5.01        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 481          |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0026618633 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.744        |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 1.07         |
# |    value_loss           | 3.04         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 482          |
# |    time_elapsed         | 532          |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0039105015 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.12         |
# |    n_updates            | 1924         |
# |    policy_gradient_loss | -0.00295     |
# |    std                  | 1.08         |
# |    value_loss           | 6.94         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 483          |
# |    time_elapsed         | 533          |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0048765717 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.11         |
# |    n_updates            | 1928         |
# |    policy_gradient_loss | 0.000407     |
# |    std                  | 1.08         |
# |    value_loss           | 4.01         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 484          |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0054618446 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.709        |
# |    n_updates            | 1932         |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 1.08         |
# |    value_loss           | 4.07         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 485          |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0061063897 |
# |    clip_fraction        | 0.0715       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.622        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.4          |
# |    n_updates            | 1936         |
# |    policy_gradient_loss | 0.00036      |
# |    std                  | 1.08         |
# |    value_loss           | 8.61         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 486          |
# |    time_elapsed         | 536          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0040007434 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.709        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.32         |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00172     |
# |    std                  | 1.08         |
# |    value_loss           | 6.78         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 487          |
# |    time_elapsed         | 537          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0024901796 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.09         |
# |    n_updates            | 1944         |
# |    policy_gradient_loss | 0.00193      |
# |    std                  | 1.08         |
# |    value_loss           | 5.07         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 488          |
# |    time_elapsed         | 538          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0037295865 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.26         |
# |    n_updates            | 1948         |
# |    policy_gradient_loss | -0.00297     |
# |    std                  | 1.08         |
# |    value_loss           | 7.02         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1855        |
# |    iterations           | 489         |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.004879615 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.932       |
# |    n_updates            | 1952        |
# |    policy_gradient_loss | -0.000646   |
# |    std                  | 1.08        |
# |    value_loss           | 5.89        |
# -----------------------------------------
# Training complete! Saving model and metrics...
# Model and metrics saved!
