# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.utils import set_random_seed
import torch.multiprocessing as mp

import pygame
import matplotlib.pyplot as plt
import time

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Constants
FULL_VIEW_SIZE = (1200, 800)
MAX_SPEED = 3
DOT_RADIUS = 30
TARGET_RADIUS = 10
GOAL_DETECTION_RADIUS = DOT_RADIUS + TARGET_RADIUS
START_POS = [FULL_VIEW_SIZE[0] // 2, FULL_VIEW_SIZE[1] // 2]
NOISE_MAGNITUDE = 0.5

# Colors
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)
GREEN = (0, 200, 0)
BLUE = (0, 0, 255)
YELLOW = (255, 255, 0)

class OptimizedCustomFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 128):
        super().__init__(observation_space, features_dim)
        
        n_input = int(np.prod(observation_space.shape))
        
        self.network = nn.Sequential(
            nn.Linear(n_input, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Linear(256, features_dim),
            nn.ReLU(),
            nn.BatchNorm1d(features_dim)
        )
        
        # Initialize weights properly
        for m in self.network.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0)
                
    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.network(observations)

class MetricsCallback(BaseCallback):
    """
    Modified callback that tracks:
      - Episode total rewards
      - Average gamma per episode
      - Actor loss and critic loss from SB3 logger
    Then plots:
      1. Average reward per episode
      2. Average gamma per episode
      3. Actor & Critic loss
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.episode_rewards = []
        self.episode_gammas = []
        self.current_episode_gammas = []
        self.total_reward = 0
        
        self.actor_losses = []
        self.critic_losses = []
        self.action_low = None  # Add this line
        self.action_high = None  # Add this line

    def _on_step(self):

        if self.action_low is None:
            self.action_low = self.model.action_space.low[0]  # 0.0
            self.action_high = self.model.action_space.high[0]  # 0.4

        if torch.is_tensor(self.locals['actions']):
            gamma = self.locals['actions'][0].item()
        else:
            gamma = float(self.locals['actions'][0])

        gamma = np.clip(gamma, self.action_low, self.action_high)
        self.current_episode_gammas.append(gamma)

        
        # Track rewards
        if torch.is_tensor(self.locals['rewards']):
            reward = self.locals['rewards'][0].item()
        else:
            reward = float(self.locals['rewards'][0])
        self.total_reward += reward
        
        # Grab actor/critic loss from the SB3 logger if available
        if (hasattr(self.model, 'logger') 
            and hasattr(self.model.logger, 'name_to_value')):
            # Actor (policy) loss
            if 'train/policy_gradient_loss' in self.model.logger.name_to_value:
                self.actor_losses.append(
                    self.model.logger.name_to_value['train/policy_gradient_loss']
                )
            # Critic (value) loss
            if 'train/value_loss' in self.model.logger.name_to_value:
                self.critic_losses.append(
                    self.model.logger.name_to_value['train/value_loss']
                )
        
        # Check if the episode ended
        if self.locals['dones'][0]:
            # Store final metrics of this episode
            self.episode_rewards.append(self.total_reward)
            self.episode_gammas.append(np.mean(self.current_episode_gammas))
            
            # Reset for next episode
            self.current_episode_gammas = []
            self.total_reward = 0
        
        return True

    def save_metrics(self, save_dir="training_metrics"):
        os.makedirs(save_dir, exist_ok=True)
        
        # 1) Plot average reward per episode
        plt.figure(figsize=(8, 5))
        plt.plot(self.episode_rewards, label="Episode Reward")
        plt.title('Average Reward per Episode')
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.grid(True)
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'average_reward.png'))
        plt.close()
        
        # 2) Plot average gamma per episode
        plt.figure(figsize=(8, 5))
        plt.plot(self.episode_gammas, label="Average Gamma")
        plt.title('Average Gamma per Episode')
        plt.xlabel('Episode')
        plt.ylabel('Gamma')
        plt.grid(True)
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'average_gamma.png'))
        plt.close()
        
        # 3) Plot actor & critic loss (if we have them)
        if self.actor_losses and self.critic_losses:
            plt.figure(figsize=(8, 5))
            plt.plot(self.actor_losses, label="Actor Loss")
            plt.plot(self.critic_losses, label="Critic Loss")
            plt.title('Actor & Critic Loss')
            plt.xlabel('Training Update (not per step)')
            plt.ylabel('Loss')
            plt.grid(True)
            plt.legend()
            plt.savefig(os.path.join(save_dir, 'actor_critic_loss.png'))
            plt.close()

        # (Optional) Save summary stats
        with open(os.path.join(save_dir, 'training_summary.txt'), 'w') as f:
            f.write(f"Total Episodes: {len(self.episode_rewards)}\n")
            if len(self.episode_rewards) > 0:
                f.write(f"Overall Average Reward: {np.mean(self.episode_rewards):.3f}\n")
                f.write(f"Overall Average Gamma: {np.mean(self.episode_gammas):.3f}\n")
                f.write(f"Best Episode Reward: {max(self.episode_rewards):.3f}\n")
                f.write(f"Worst Episode Reward: {min(self.episode_rewards):.3f}\n")

class DynamicArbitrationEnv(gym.Env):
    """
    Modified so that gamma is always in [0.0, 0.4].
    A custom reward encourages gamma near 0.4 when close to the goal,
    and gamma near 0.1 when far from the goal.
    """
    def __init__(self, render_mode=None):
        super().__init__()
        self.render_mode = render_mode
        self.max_dist = np.sqrt(FULL_VIEW_SIZE[0]**2 + FULL_VIEW_SIZE[1]**2)
        if render_mode == "human":
            pygame.init()
            self.screen = pygame.display.set_mode(FULL_VIEW_SIZE)
            pygame.display.set_caption("Training Visualization")
            self.font = pygame.font.Font(None, 24)
        
        # Observation space: [dot_pos_x, dot_pos_y, human_input_x, human_input_y, 
        #                    target_pos_x, target_pos_y, perfect_dir_x, perfect_dir_y]
        self.observation_space = spaces.Box(
            low=np.array([0, 0, -1, -1, 0, 0, -1, -1, 0]),
            high=np.array([
                FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1],
                1, 1,
                FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1],
                1, 1, 1
            ], dtype=np.float32),
            dtype=np.float32
        )
        
        # Action space: gamma value between 0.0 and 0.4
        self.action_space = spaces.Box(
            low=np.array([0.0]),
            high=np.array([0.4]),
            dtype=np.float32
        )
        
        self.dot_pos = None
        self.target_pos = None
        self.step_count = 0
        self.max_steps = 300
        self.last_render_time = time.time()
        self.steps_since_target_change = 0
        self.change_target_interval = 50  # Change target every N steps
        

    def _generate_target(self):
        x = np.random.uniform(100, FULL_VIEW_SIZE[0] - 100)
        y = np.random.uniform(100, FULL_VIEW_SIZE[1] - 100)
        return np.array([x, y], dtype=np.float32)

    def _get_obs(self):
        to_target = self.target_pos - self.dot_pos
        dist = np.linalg.norm(to_target)
        perfect_dir = to_target / dist if dist > 0 else np.array([0, 0])
        to_target = self.target_pos - self.dot_pos
        dist_to_target = np.linalg.norm(to_target)
        normalized_dist = dist_to_target / self.max_dist
        
        # Simulate "human" input with some noise
        noise = np.random.normal(0, NOISE_MAGNITUDE, size=2)
        human_input = perfect_dir + noise
        if np.linalg.norm(human_input) > 0:
            human_input = human_input / np.linalg.norm(human_input)
        

        

        return np.concatenate([
            self.dot_pos,
            human_input,
            self.target_pos,
            perfect_dir,
            [normalized_dist]
        ])

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.dot_pos = np.array(START_POS, dtype=np.float32)
        self.target_pos = self._generate_target()
        self.step_count = 0
        self.steps_since_target_change = 0
        return self._get_obs(), {}

    def step(self, action):
        self.step_count += 1
        self.steps_since_target_change += 1
        
        # Gamma is clipped to [0.0, 0.4]
        if isinstance(action, (np.ndarray, list)):
            gamma = float(np.clip(action[0], 0.0, 0.4))
        else:
            gamma = float(np.clip(action, 0.0, 0.4))
        
        obs = self._get_obs()
        human_input = obs[2:4]
        perfect_dir = obs[6:8]
        
        # Combine directions
        combined_dir = gamma * perfect_dir + (1 - gamma) * human_input
        if np.linalg.norm(combined_dir) > 0:
            combined_dir = combined_dir / np.linalg.norm(combined_dir)
        
        # Move agent
        move_speed = combined_dir * MAX_SPEED
        new_pos = self.dot_pos + move_speed
        self.dot_pos = np.clip(new_pos, [0, 0], [FULL_VIEW_SIZE[0], FULL_VIEW_SIZE[1]])
        
        # Distance-based rewards
        dist_to_target = np.linalg.norm(self.target_pos - self.dot_pos)
        max_dist = np.sqrt(FULL_VIEW_SIZE[0]**2 + FULL_VIEW_SIZE[1]**2)
        
        # 1) Progress reward: negative of normalized distance
        progress_reward = -dist_to_target / max_dist
        
        # 2) Encourage gamma near 0.4 if close to goal, near 0.1 if far:
        #    ideal_gamma goes from 0.4 (dist=0) to 0.1 (dist=max_dist)
        distance_fraction = dist_to_target / max_dist
        ideal_gamma = 0.4 - 0.3 * distance_fraction  # linear interpolation
        # Clip it just to be safe:
        ideal_gamma = np.clip(ideal_gamma, 0.1, 0.4)
        
        # Negative penalty for deviating from ideal gamma
        gamma_penalty = -(gamma - ideal_gamma)**2
        
        # 3) Additional bonus if combined_dir aligns with "human" input
        human_alignment = np.dot(combined_dir, human_input)
        human_follow_reward = 0.5 * human_alignment
        
        # 4) Total reward
        #    Weighted sum of terms (you can tweak the coefficients):
        reward = 0.00005*progress_reward + 0.1 * gamma_penalty +  human_follow_reward
        
        # Occasionally change target
        if self.steps_since_target_change >= self.change_target_interval:
            self.target_pos = self._generate_target()
            self.steps_since_target_change = 0
            reward += 0.5  # small bonus for changing target
        
        # Check termination
        terminated = False
        truncated = False
        
        if dist_to_target < GOAL_DETECTION_RADIUS:
            # Bonus for reaching the goal
            reward += 10.0
            terminated = True
        elif self.step_count >= self.max_steps:
            truncated = True
        
        if self.render_mode == "human":
            self.render(human_input, perfect_dir, combined_dir, gamma, reward)
        
        return self._get_obs(), reward, terminated, truncated, {}

    def render(self, human_input, perfect_dir, combined_dir, gamma, reward):
        # Basic pygame rendering at ~60 FPS
        current_time = time.time()
        if current_time - self.last_render_time < 1/60:
            return
        self.last_render_time = current_time
        
        self.screen.fill(WHITE)
        
        pygame.draw.circle(self.screen, YELLOW, 
                           (int(self.target_pos[0]), int(self.target_pos[1])), 
                           TARGET_RADIUS)
        
        pygame.draw.circle(self.screen, BLACK, 
                           (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                           DOT_RADIUS, 2)
        
        arrow_length = 50
        
        # Perfect direction (green)
        end_pos = (int(self.dot_pos[0] + perfect_dir[0] * arrow_length),
                   int(self.dot_pos[1] + perfect_dir[1] * arrow_length))
        pygame.draw.line(self.screen, GREEN, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
                        
        # Human direction (blue)
        end_pos = (int(self.dot_pos[0] + human_input[0] * arrow_length),
                   int(self.dot_pos[1] + human_input[1] * arrow_length))
        pygame.draw.line(self.screen, BLUE, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
                        
        # Combined direction (red)
        end_pos = (int(self.dot_pos[0] + combined_dir[0] * arrow_length),
                   int(self.dot_pos[1] + combined_dir[1] * arrow_length))
        pygame.draw.line(self.screen, RED, 
                         (int(self.dot_pos[0]), int(self.dot_pos[1])), 
                         end_pos, 2)
        
        texts = [
            f"Step: {self.step_count}",
            f"Gamma: {gamma:.2f}",
            f"Reward: {reward:.2f}",
            f"Steps until target change: {self.change_target_interval - self.steps_since_target_change}"
        ]
        
        for i, text in enumerate(texts):
            text_surface = self.font.render(text, True, BLACK)
            self.screen.blit(text_surface, (10, 10 + i*25))
        
        pygame.display.flip()

def make_env(rank, seed=0):
    def _init():
        env = DynamicArbitrationEnv(render_mode=None)
        env.reset(seed=seed + rank)
        return env
    set_random_seed(seed)
    return _init

def train():
    # You can switch back to SubprocVecEnv if needed, but DummyVecEnv is simpler to debug
    n_envs = 8
    env = DummyVecEnv([make_env(i) for i in range(n_envs)])
    
    policy_kwargs = dict(
        features_extractor_class=OptimizedCustomFeaturesExtractor,
        features_extractor_kwargs=dict(features_dim=128),
        net_arch=dict(pi=[256, 128],
                      vf=[256, 128])
    )
    
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=2.5e-4,
        n_steps=256,
        batch_size=128,
        ent_coef=0.01,
        n_epochs=4,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        normalize_advantage=True,
        policy_kwargs=policy_kwargs,
        device=device,
        verbose=1
    )
    
    # Create metrics callback
    metrics_callback = MetricsCallback()
    
    try:
        print("Starting training...")
        model.learn(
            total_timesteps=2000000,
            callback=metrics_callback
        )
        
        print("Training complete! Saving model and metrics...")
        model.save("dynamic_arbitration_ppo_optimized")
        metrics_callback.save_metrics()
        print("Model and metrics saved!")
        
    except KeyboardInterrupt:
        print("\nTraining interrupted. Saving current model and metrics...")
        model.save("dynamic_arbitration_ppo_optimized_interrupted")
        metrics_callback.save_metrics(save_dir="training_metrics_interrupted")
    
    finally:
        env.close()
        pygame.quit()

if __name__ == "__main__":
    mp.set_start_method('spawn', force=True)
    train()
# Out:
# Using device: cuda
# Using cuda device
# Starting training...
# C:\Users\tnlab\AppData\Local\Temp\ipykernel_15828\1859255874.py:97: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   gamma = float(self.locals['actions'][0])
# -----------------------------
# | time/              |      |
# |    fps             | 3461 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2739         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0015287763 |
# |    clip_fraction        | 0.00366      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0231       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.65         |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00137     |
# |    std                  | 1.01         |
# |    value_loss           | 37.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2619         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0018985226 |
# |    clip_fraction        | 0.005        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.38         |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 1.01         |
# |    value_loss           | 22.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2488         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0011315119 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.61         |
# |    n_updates            | 12           |
# |    policy_gradient_loss | 0.000726     |
# |    std                  | 1.01         |
# |    value_loss           | 16.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2482         |
# |    iterations           | 5            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0007674531 |
# |    clip_fraction        | 0.00061      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.88         |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.000112    |
# |    std                  | 1            |
# |    value_loss           | 15.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2504         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0026801848 |
# |    clip_fraction        | 0.00891      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.88         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | 3.95e-05     |
# |    std                  | 0.997        |
# |    value_loss           | 16           |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2529          |
# |    iterations           | 7             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00090373494 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.203         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 12.2          |
# |    n_updates            | 24            |
# |    policy_gradient_loss | 0.000597      |
# |    std                  | 0.994         |
# |    value_loss           | 23.5          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2553         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0010453203 |
# |    clip_fraction        | 0.00354      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13           |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.000527    |
# |    std                  | 0.993        |
# |    value_loss           | 26.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2567         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0009904281 |
# |    clip_fraction        | 0.00281      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.000244     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.69         |
# |    n_updates            | 32           |
# |    policy_gradient_loss | 0.000803     |
# |    std                  | 0.993        |
# |    value_loss           | 17.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2576         |
# |    iterations           | 10           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0018718618 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.16         |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.000883    |
# |    std                  | 0.991        |
# |    value_loss           | 15           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2581         |
# |    iterations           | 11           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0012598415 |
# |    clip_fraction        | 0.00208      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.405        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.08         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000467    |
# |    std                  | 0.99         |
# |    value_loss           | 18.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2573         |
# |    iterations           | 12           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0013829869 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.412        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.06         |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.000836    |
# |    std                  | 0.989        |
# |    value_loss           | 27.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2577        |
# |    iterations           | 13          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003191925 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.117      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.81        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | 3.78e-05    |
# |    std                  | 0.988       |
# |    value_loss           | 16.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2578         |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0023531853 |
# |    clip_fraction        | 0.00574      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0963       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.32         |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.000427    |
# |    std                  | 0.986        |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2581         |
# |    iterations           | 15           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0009007623 |
# |    clip_fraction        | 0.00232      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.299        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.03         |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 0.987        |
# |    value_loss           | 12.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2583         |
# |    iterations           | 16           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0023362404 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.35         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 0.000496     |
# |    std                  | 0.985        |
# |    value_loss           | 10.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2585         |
# |    iterations           | 17           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0015404851 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 34.8         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | 0.00225      |
# |    std                  | 0.985        |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2586         |
# |    iterations           | 18           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0022893143 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0949       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.06         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | 0.00134      |
# |    std                  | 0.985        |
# |    value_loss           | 49.3         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2577          |
# |    iterations           | 19            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00059678336 |
# |    clip_fraction        | 0.00159       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.103         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 10.8          |
# |    n_updates            | 72            |
# |    policy_gradient_loss | 0.000638      |
# |    std                  | 0.986         |
# |    value_loss           | 32.6          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2579         |
# |    iterations           | 20           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0035408218 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.112       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.91         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00134     |
# |    std                  | 0.984        |
# |    value_loss           | 16           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2579         |
# |    iterations           | 21           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0015924061 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.56         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000946     |
# |    std                  | 0.984        |
# |    value_loss           | 37.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2580         |
# |    iterations           | 22           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0023715186 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.31         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00377     |
# |    std                  | 0.983        |
# |    value_loss           | 20.3         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2570       |
# |    iterations           | 23         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00393105 |
# |    clip_fraction        | 0.02       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.77       |
# |    n_updates            | 88         |
# |    policy_gradient_loss | -0.00181   |
# |    std                  | 0.984      |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2564         |
# |    iterations           | 24           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0016417508 |
# |    clip_fraction        | 0.00842      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.165       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.22         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00243     |
# |    std                  | 0.984        |
# |    value_loss           | 16.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2557         |
# |    iterations           | 25           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0031438977 |
# |    clip_fraction        | 0.00964      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.417        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.77         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 0.982        |
# |    value_loss           | 10.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2550        |
# |    iterations           | 26          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.001089823 |
# |    clip_fraction        | 0.00488     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.94        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.000393    |
# |    std                  | 0.981       |
# |    value_loss           | 64.2        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2546          |
# |    iterations           | 27            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00097600406 |
# |    clip_fraction        | 0.00293       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.128         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.79          |
# |    n_updates            | 104           |
# |    policy_gradient_loss | -0.000275     |
# |    std                  | 0.983         |
# |    value_loss           | 46.5          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2547          |
# |    iterations           | 28            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00066749204 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.534         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.04          |
# |    n_updates            | 108           |
# |    policy_gradient_loss | -0.000399     |
# |    std                  | 0.986         |
# |    value_loss           | 17.4          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2544        |
# |    iterations           | 29          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.001798646 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.5         |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.000747   |
# |    std                  | 0.985       |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2546        |
# |    iterations           | 30          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.001829697 |
# |    clip_fraction        | 0.00671     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.2        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.000714   |
# |    std                  | 0.985       |
# |    value_loss           | 38.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2547         |
# |    iterations           | 31           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0015607367 |
# |    clip_fraction        | 0.00464      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0803       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.13         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 0.986        |
# |    value_loss           | 23.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2544         |
# |    iterations           | 32           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0010579416 |
# |    clip_fraction        | 0.00427      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.8         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | 0.00128      |
# |    std                  | 0.986        |
# |    value_loss           | 23.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2545         |
# |    iterations           | 33           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0034907563 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.99         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | 0.000967     |
# |    std                  | 0.987        |
# |    value_loss           | 18.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2547         |
# |    iterations           | 34           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0017307492 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.51         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | 0.00164      |
# |    std                  | 0.987        |
# |    value_loss           | 25.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2549         |
# |    iterations           | 35           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0013773192 |
# |    clip_fraction        | 0.00256      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.438        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.87         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 0.989        |
# |    value_loss           | 14.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2551         |
# |    iterations           | 36           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0017867195 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.96         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00285     |
# |    std                  | 0.991        |
# |    value_loss           | 15.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2554         |
# |    iterations           | 37           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0022479848 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.085        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.04         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00571     |
# |    std                  | 0.993        |
# |    value_loss           | 17.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2555         |
# |    iterations           | 38           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0010097106 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.45         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | 0.00137      |
# |    std                  | 0.99         |
# |    value_loss           | 34.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2555         |
# |    iterations           | 39           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0019455943 |
# |    clip_fraction        | 0.00867      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.41         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 0.000522     |
# |    std                  | 0.992        |
# |    value_loss           | 24.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2555         |
# |    iterations           | 40           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0040585613 |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.407        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.2         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.993        |
# |    value_loss           | 55.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2554        |
# |    iterations           | 41          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003141938 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.93        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000642   |
# |    std                  | 0.994       |
# |    value_loss           | 33.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2553         |
# |    iterations           | 42           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0017424494 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.83         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | 0.000681     |
# |    std                  | 0.994        |
# |    value_loss           | 24.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2553         |
# |    iterations           | 43           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0029639592 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00935     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.26         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | 9.44e-05     |
# |    std                  | 0.992        |
# |    value_loss           | 25.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2551        |
# |    iterations           | 44          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003600818 |
# |    clip_fraction        | 0.0179      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.41        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.000246   |
# |    std                  | 0.993       |
# |    value_loss           | 14.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2549       |
# |    iterations           | 45         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00424909 |
# |    clip_fraction        | 0.0225     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.464      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.42       |
# |    n_updates            | 176        |
# |    policy_gradient_loss | 0.000671   |
# |    std                  | 0.987      |
# |    value_loss           | 10.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2550        |
# |    iterations           | 46          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004740023 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.124      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.78        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 7.21e-05    |
# |    std                  | 0.984       |
# |    value_loss           | 11.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2551         |
# |    iterations           | 47           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0053237528 |
# |    clip_fraction        | 0.0795       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.401        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.04         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | 0.00122      |
# |    std                  | 0.983        |
# |    value_loss           | 12.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2552        |
# |    iterations           | 48          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009448682 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.43        |
# |    n_updates            | 188         |
# |    policy_gradient_loss | 0.00439     |
# |    std                  | 0.983       |
# |    value_loss           | 14.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2551       |
# |    iterations           | 49         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01435659 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | 0.487      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 10.3       |
# |    n_updates            | 192        |
# |    policy_gradient_loss | 0.000439   |
# |    std                  | 0.984      |
# |    value_loss           | 51.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2551        |
# |    iterations           | 50          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.003434564 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.75        |
# |    n_updates            | 196         |
# |    policy_gradient_loss | 0.00209     |
# |    std                  | 0.985       |
# |    value_loss           | 17.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2550         |
# |    iterations           | 51           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0042203027 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.515        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.23         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.99         |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2550         |
# |    iterations           | 52           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0025752294 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.94         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | 0.000695     |
# |    std                  | 0.993        |
# |    value_loss           | 11.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2548         |
# |    iterations           | 53           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0047750454 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.657        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.3          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 0.99         |
# |    value_loss           | 10.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2545         |
# |    iterations           | 54           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0035123914 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.14         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.0029      |
# |    std                  | 0.99         |
# |    value_loss           | 13.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2541         |
# |    iterations           | 55           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0046682106 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.23         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00222     |
# |    std                  | 0.992        |
# |    value_loss           | 10.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2540         |
# |    iterations           | 56           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0016485774 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.075        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.67         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.0039       |
# |    std                  | 0.992        |
# |    value_loss           | 28.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2539         |
# |    iterations           | 57           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0029095458 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0121       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.91         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000999    |
# |    std                  | 0.991        |
# |    value_loss           | 27.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2537         |
# |    iterations           | 58           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0027997333 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.32         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.000202    |
# |    std                  | 0.989        |
# |    value_loss           | 9.88         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2536         |
# |    iterations           | 59           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0026911106 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.07         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00348     |
# |    std                  | 0.994        |
# |    value_loss           | 11.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2536         |
# |    iterations           | 60           |
# |    time_elapsed         | 48           |
# ...
# |    total_timesteps      | 1017856      |
# | train/                  |              |
# |    approx_kl            | 0.0024940977 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.96         |
# |    n_updates            | 1984         |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 1.02         |
# |    value_loss           | 10.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2510        |
# |    iterations           | 498         |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 1019904     |
# | train/                  |             |
# |    approx_kl            | 0.005587849 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.24        |
# |    n_updates            | 1988        |
# |    policy_gradient_loss | 0.000799    |
# |    std                  | 1.02        |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 499          |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 1021952      |
# | train/                  |              |
# |    approx_kl            | 0.0039060833 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.506        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.1          |
# |    n_updates            | 1992         |
# |    policy_gradient_loss | 0.00163      |
# |    std                  | 1.03         |
# |    value_loss           | 15.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 500          |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 1024000      |
# | train/                  |              |
# |    approx_kl            | 0.0056350026 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.02         |
# |    n_updates            | 1996         |
# |    policy_gradient_loss | -6.04e-05    |
# |    std                  | 1.02         |
# |    value_loss           | 26.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 501          |
# |    time_elapsed         | 408          |
# |    total_timesteps      | 1026048      |
# | train/                  |              |
# |    approx_kl            | 0.0037980953 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.84         |
# |    n_updates            | 2000         |
# |    policy_gradient_loss | -0.000662    |
# |    std                  | 1.02         |
# |    value_loss           | 22.8         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2510       |
# |    iterations           | 502        |
# |    time_elapsed         | 409        |
# |    total_timesteps      | 1028096    |
# | train/                  |            |
# |    approx_kl            | 0.00511327 |
# |    clip_fraction        | 0.0305     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.6        |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.8        |
# |    n_updates            | 2004       |
# |    policy_gradient_loss | -0.00212   |
# |    std                  | 1.02       |
# |    value_loss           | 11.3       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2511         |
# |    iterations           | 503          |
# |    time_elapsed         | 410          |
# |    total_timesteps      | 1030144      |
# | train/                  |              |
# |    approx_kl            | 0.0099899825 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.02         |
# |    n_updates            | 2008         |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 1.02         |
# |    value_loss           | 6.74         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2511         |
# |    iterations           | 504          |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 1032192      |
# | train/                  |              |
# |    approx_kl            | 0.0038828542 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0251       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.88         |
# |    n_updates            | 2012         |
# |    policy_gradient_loss | -0.000601    |
# |    std                  | 1.02         |
# |    value_loss           | 16.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2511        |
# |    iterations           | 505         |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 1034240     |
# | train/                  |             |
# |    approx_kl            | 0.007822333 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.64        |
# |    n_updates            | 2016        |
# |    policy_gradient_loss | 0.00329     |
# |    std                  | 1.02        |
# |    value_loss           | 17.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2511        |
# |    iterations           | 506         |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 1036288     |
# | train/                  |             |
# |    approx_kl            | 0.008639111 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.74        |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | 0.00245     |
# |    std                  | 1.01        |
# |    value_loss           | 14.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2511         |
# |    iterations           | 507          |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 1038336      |
# | train/                  |              |
# |    approx_kl            | 0.0063972757 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.49         |
# |    n_updates            | 2024         |
# |    policy_gradient_loss | -0.000303    |
# |    std                  | 1.01         |
# |    value_loss           | 9.21         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2511         |
# |    iterations           | 508          |
# |    time_elapsed         | 414          |
# |    total_timesteps      | 1040384      |
# | train/                  |              |
# |    approx_kl            | 0.0021138904 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.75         |
# |    n_updates            | 2028         |
# |    policy_gradient_loss | -0.00177     |
# |    std                  | 1.02         |
# |    value_loss           | 13.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2511        |
# |    iterations           | 509         |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 1042432     |
# | train/                  |             |
# |    approx_kl            | 0.005109571 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.55        |
# |    n_updates            | 2032        |
# |    policy_gradient_loss | -0.000306   |
# |    std                  | 1.02        |
# |    value_loss           | 7.74        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 510          |
# |    time_elapsed         | 415          |
# |    total_timesteps      | 1044480      |
# | train/                  |              |
# |    approx_kl            | 0.0037679006 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.88         |
# |    n_updates            | 2036         |
# |    policy_gradient_loss | -5.32e-05    |
# |    std                  | 1.02         |
# |    value_loss           | 11           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 511          |
# |    time_elapsed         | 416          |
# |    total_timesteps      | 1046528      |
# | train/                  |              |
# |    approx_kl            | 0.0024457616 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.07         |
# |    n_updates            | 2040         |
# |    policy_gradient_loss | 0.0011       |
# |    std                  | 1.02         |
# |    value_loss           | 7.74         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2510       |
# |    iterations           | 512        |
# |    time_elapsed         | 417        |
# |    total_timesteps      | 1048576    |
# | train/                  |            |
# |    approx_kl            | 0.00457725 |
# |    clip_fraction        | 0.0529     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.414      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.06       |
# |    n_updates            | 2044       |
# |    policy_gradient_loss | 0.00145    |
# |    std                  | 1.02       |
# |    value_loss           | 10.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2510        |
# |    iterations           | 513         |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 1050624     |
# | train/                  |             |
# |    approx_kl            | 0.004309838 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.51        |
# |    n_updates            | 2048        |
# |    policy_gradient_loss | 0.00251     |
# |    std                  | 1.02        |
# |    value_loss           | 9.25        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 514          |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 1052672      |
# | train/                  |              |
# |    approx_kl            | 0.0061625363 |
# |    clip_fraction        | 0.0784       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.68         |
# |    n_updates            | 2052         |
# |    policy_gradient_loss | 0.00155      |
# |    std                  | 1.02         |
# |    value_loss           | 11.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2510        |
# |    iterations           | 515         |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 1054720     |
# | train/                  |             |
# |    approx_kl            | 0.004390409 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.18        |
# |    n_updates            | 2056        |
# |    policy_gradient_loss | 0.00101     |
# |    std                  | 1.02        |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2510         |
# |    iterations           | 516          |
# |    time_elapsed         | 420          |
# |    total_timesteps      | 1056768      |
# | train/                  |              |
# |    approx_kl            | 0.0061894367 |
# |    clip_fraction        | 0.0765       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.86         |
# |    n_updates            | 2060         |
# |    policy_gradient_loss | 0.00242      |
# |    std                  | 1.02         |
# |    value_loss           | 14.6         |
# ------------------------------------------
#
# Training interrupted. Saving current model and metrics...
