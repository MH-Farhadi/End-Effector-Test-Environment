# %%
import pygame
import sys

pygame.init()
pygame.joystick.init()

if pygame.joystick.get_count() == 0:
    print("No joystick detected. Please connect a controller and re-run.")
    sys.exit(1)

joystick = pygame.joystick.Joystick(0)
joystick.init()

print("Joystick initialized:", joystick.get_name())
print("Number of axes:", joystick.get_numaxes())

running = True
clock = pygame.time.Clock()

while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        # Optional: Press 'ESC' key to quit
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_ESCAPE:
                running = False

    # Clear the screen by printing a separator line (to keep console output readable)
    print("-" * 30)

    # Print out the values of all axes
    num_axes = joystick.get_numaxes()
    for i in range(num_axes):
        axis_value = joystick.get_axis(i)
        print(f"Axis {i}: {axis_value:.3f}")

    # After identifying the L2 axis and its range, you can try thresholds here
    # For example, if L2 is on axis 2, and resting around 0.0 and pressed around 1.0:
    # l2_value = joystick.get_axis(2)
    # l2_pressed = l2_value > 0.5
    # print(f"L2 Pressed: {l2_pressed}")

    clock.tick(10)  # Limit updates to 10 times per second for readability

pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Joystick initialized: DualSense Wireless Controller
# Number of axes: 6
# ------------------------------
# Axis 0: 0.000
# Axis 1: 0.000
# Axis 2: 0.000
# Axis 3: 0.000
# Axis 4: 0.000
# Axis 5: 0.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.012
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.012
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.012
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.012
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.027
# Axis 1: 0.012
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.027
# Axis 1: 0.012
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.035
# Axis 1: 0.012
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.043
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -0.733
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.043
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.035
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.027
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -0.498
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -0.106
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: 0.522
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.043
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.043
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: 1.000
# ------------------------------
# Axis 0: 0.043
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: 1.000
# ------------------------------
# Axis 0: 0.035
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: 1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.020
# Axis 1: 0.020
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: -0.012
# Axis 1: 0.035
# Axis 2: -0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: -0.843
# Axis 1: 0.725
# Axis 2: 0.584
# Axis 3: -0.271
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: -0.843
# Axis 1: 0.733
# Axis 2: 0.953
# Axis 3: -0.490
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: -0.820
# Axis 1: 0.733
# Axis 2: 1.000
# Axis 3: -0.302
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: -0.404
# Axis 1: 0.702
# Axis 2: 0.427
# Axis 3: 0.396
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.067
# Axis 1: 0.020
# Axis 2: -0.161
# Axis 3: 0.349
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 1.000
# Axis 1: -0.310
# Axis 2: -0.812
# Axis 3: 0.278
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 1.000
# Axis 1: -0.310
# Axis 2: -1.000
# Axis 3: -0.137
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.867
# Axis 1: -0.365
# Axis 2: -0.922
# Axis 3: -0.569
# Axis 4: -1.000
# Axis 5: -0.914
# ------------------------------
# Axis 0: -0.757
# Axis 1: -0.765
# Axis 2: 0.506
# Axis 3: -0.922
# Axis 4: -1.000
# Axis 5: 1.000
# ------------------------------
# Axis 0: -0.922
# Axis 1: -0.522
# Axis 2: 0.851
# Axis 3: -0.035
# Axis 4: -1.000
# Axis 5: 1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ------------------------------
# Axis 0: 0.012
# Axis 1: 0.020
# Axis 2: 0.004
# Axis 3: 0.004
# Axis 4: -1.000
# Axis 5: -1.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 45
#      37         print(f"Axis {i}: {axis_value:.3f}")
#      39     # After identifying the L2 axis and its range, you can try thresholds here
#      40     # For example, if L2 is on axis 2, and resting around 0.0 and pressed around 1.0:
#      41     # l2_value = joystick.get_axis(2)
#      42     # l2_pressed = l2_value > 0.5
#      43     # print(f"L2 Pressed: {l2_pressed}")
# ---> 45     clock.tick(10)  # Limit updates to 10 times per second for readability
#      47 pygame.quit()
#
# KeyboardInterrupt:
